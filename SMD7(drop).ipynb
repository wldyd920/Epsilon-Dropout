# %% [markdown]
# train acc로 evaluation method 전환.
# 각 batch 마다, top k masks에 저장.
# exploit시에 top k masks에서 가져오기.
#
# batch별 train, test 구현.
# test acc로 evaluation method 전환.

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, random_split
from torchvision.datasets import MNIST
from torchvision.datasets import CIFAR10
from torchvision.datasets import CIFAR100
from torchvision.datasets import FashionMNIST
from torchvision.transforms import ToTensor
import matplotlib.pyplot as plt
from torchvision import datasets, transforms
from torch.nn import functional as F
import sys
import os
import math
import random

# device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device = torch.device('cuda')
print(device)
# Out:
# cuda

# %%
# Hyperparameter configurations
exp_num = -1     # To save the result, change every time. -1 to not save.
total_epoch = 200
learning_rate = 0.01
dropout_prob = 0.5
top_k = 10
if exp_num!=-1: os.mkdir(f'./Result{exp_num}')

# %%
def dataset_MNIST():
  transform = transforms.Compose([transforms.ToTensor(),
                                  transforms.Normalize((0.1307,), (0.3081,))])
  train_dataset = MNIST(root='../data', train=True, download=True, transform=transform)
  test_dataset = MNIST(root='../data', train=False, download=True, transform=transform)
  train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True, drop_last=True)
  test_loader = DataLoader(test_dataset, batch_size=64, shuffle=True, drop_last=True)
  return train_loader, test_loader

def dataset_FMNIST():
  transform = transforms.Compose([transforms.ToTensor(),
                                  transforms.Normalize((0.2860,), (0.3530,))])
  train_dataset = FashionMNIST(root='../data', train=True, download=True, transform=transform)
  test_dataset = FashionMNIST(root='../data', train=False, download=True, transform=transform)
  train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True, drop_last=True)
  test_loader = DataLoader(test_dataset, batch_size=64, shuffle=True, drop_last=True)
  return train_loader, test_loader

def dataset_CIFAR10():
  transform = transforms.Compose([transforms.ToTensor(),
                                  transforms.Normalize((0.4914, 0.4822, 0.4465), (0.247, 0.243, 0.261))])
  
  train_dataset = CIFAR10(root='../data', train=True, download=True, transform=transform)
  train_dataset, valid_dataset = random_split(train_dataset, [(len(train_dataset)//5)*4, (len(train_dataset)//5)*1])
  test_dataset = CIFAR10(root='../data', train=False, download=True, transform=transform)

  train_loader = DataLoader(train_dataset, batch_size=40, shuffle=True, drop_last=True)
  valid_loader = DataLoader(valid_dataset, batch_size=10, shuffle=True, drop_last=True)
  test_loader = DataLoader(test_dataset, batch_size=10, shuffle=True, drop_last=True)
  return train_loader, valid_loader, test_loader
  # return train_loader, test_loader

def dataset_CIFAR100():
  transform = transforms.Compose([transforms.ToTensor(),
                                  transforms.Normalize((0.5071, 0.4867, 0.4408), (0.2675, 0.2565, 0.2761))])
  
  train_dataset = CIFAR100(root='../data', train=True, download=True, transform=transform)
  train_dataset, valid_dataset = random_split(train_dataset, [len(train_dataset)//2, len(train_dataset)//2])
  test_dataset = CIFAR100(root='../data', train=False, download=True, transform=transform)

  train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True, drop_last=True)
  valid_loader = DataLoader(valid_dataset, batch_size=64, shuffle=True, drop_last=True)
  test_loader = DataLoader(test_dataset, batch_size=64, shuffle=True, drop_last=True)
  return train_loader, test_loader

# %%
def Run(dataset, method):
    # Choose dataset
    if dataset=='MNIST': train_loader, test_loader = dataset_MNIST()
    elif dataset=='FMNIST': train_loader, test_loader = dataset_FMNIST()
    elif dataset=='CIFAR10': train_loader, valid_loader, test_loader= dataset_CIFAR10()
    elif dataset=='CIFAR100': train_loader, valid_loader, test_loader = dataset_CIFAR100()
    print(f'Finished loading {dataset} dataset')
    
    # Save log
    if exp_num!=-1:
        sys.stdout = open(f'./Result{exp_num}/{dataset}_{method}.txt', 'w')
        sys.stdout = open(f'./Result{exp_num}/{dataset}_{method}.txt', 'a')
    
    train_acc_list = []
    val_acc_list = []
    train_loss_list = []
    val_loss_list = []
    for epoch in range(total_epoch):
        train_loss, train_correct, val_loss, val_correct = 0,0,0,0
        train_iter = iter(train_loader)
        val_iter = iter(valid_loader)
        for i in range(len(train_loader)):
            # Train
            model.train()
            (data, target) = next(train_iter)
            data, target = data.to(device), target.to(device)
            optimizer.zero_grad()
            output = model(data, epoch)
            loss = criterion(output, target)
            loss.backward()
            optimizer.step()
            train_loss += loss.item()
            train_correct += (output.argmax(1) == target).sum().item()
            
            # Validation
            model.eval()
            with torch.no_grad():
                (data, target) = next(val_iter)
                data, target = data.to(device), target.to(device)
                output = model(data, epoch)
                loss = criterion(output, target)
                val_loss += loss.item()
                val_correct += (output.argmax(1) == target).sum().item()
                # model.record_acc((output.argmax(1) == target).sum().item())  # EVAL MASK!!!

        train_loss /= len(train_loader.dataset)
        train_accuracy = train_correct / len(train_loader.dataset)
        train_acc_list.append(train_accuracy)
        train_loss_list.append(train_loss) 

        val_loss /= len(valid_loader.dataset)
        val_accuracy = val_correct / len(valid_loader.dataset)
        val_acc_list.append(val_accuracy)
        val_loss_list.append(val_loss)

        # Show Result
        print(f'Epoch {epoch + 1:2d} | '
            f'Train Loss: {train_loss:.4f} | Train Accuracy: {round(train_accuracy*100, 2)} | '
            f'Val Loss: {val_loss:.4f} | Val Accuracy: {round(val_accuracy*100, 2)}')
    return train_loss_list, train_acc_list, val_loss_list, val_acc_list


# 그래프
def plot(dataset, method, exp_num):
    figname = f"[{dataset}] {method}  #{exp_num}.svg"
    plt.figure(figsize=(10, 6), dpi=100)
    plt.plot(train_acc_list, label='Train_acc')
    plt.plot(test_acc_list, label='Validation_acc')
    plt.plot(train_loss_list, label='Train_loss')
    plt.plot(test_loss_list, label='Validation_loss')
    plt.legend()
    plt.title('Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    if exp_num != -1 : plt.savefig(f'./Result{exp_num}/'+figname, format='svg')
    plt.show()

# %%
class SMD(nn.Module):
    def __init__(self, p=0.5, total_epoch=10, k=1):
        super(SMD, self).__init__()
        self.p = p
        self.total_epoch = total_epoch
        self.topk_masks = []
        self.mask = None
        self.accs = []
        self.k = k
        self.using_mask = False

    def forward(self, x, curr_epoch):
        if self.training:
            if curr_epoch <= (self.total_epoch/2):
                self.mask = (torch.rand_like(x) > self.p).float().to(device)
                self.using_mask = False
                x = x * self.mask / (1 - self.p)
                # x = x * self.mask 
                x = x.to(device)
                return x
            elif curr_epoch > (self.total_epoch/2):
                self.mask_idx = self.accs.index(random.choice(self.accs))
                self.mask = self.topk_masks[self.mask_idx]
                self.using_mask = True
                x = x * self.mask / (1 - self.p)
                x.to(device)
                return x
        if not self.training:
            return x

    # 중복마스크 저장하던 오류 제거
    def record_acc(self, acc):
        if len(self.topk_masks) < self.k:
            self.topk_masks.append(self.mask)
            self.accs.append(acc)
        elif len(self.topk_masks) >= self.k:    
            lowest = min(self.accs)
            if self.using_mask == True:
                if acc > lowest:
                    self.accs[self.mask_idx] = acc
            elif self.using_mask == False:
                if acc > lowest:
                    lowest_idx = self.accs.index(lowest)
                    self.topk_masks.pop(lowest_idx)
                    self.accs.pop(lowest_idx)
                    self.topk_masks.append(self.mask)
                    self.accs.append(acc)

# %%
class Net_MNIST(nn.Module):
    def __init__(self):
        super(Net_MNIST, self).__init__()
        self.conv1 = nn.Conv2d(1, 64, 3, 1, padding=1)
        self.conv2 = nn.Conv2d(64, 64, 3, 1)
        self.conv3 = nn.Conv2d(64, 128, 3, 1)
        self.conv4 = nn.Conv2d(128, 128, 3, 1)
        self.fc1 = nn.Linear(4*4*128, 4096)
        self.fc2 = nn.Linear(4096, 4096)
        self.fc3 = nn.Linear(4096, 10)
        self.smd1 = SMD(p=dropout_prob, total_epoch=total_epoch, k=top_k)
        self.smd2 = SMD(p=dropout_prob, total_epoch=total_epoch, k=top_k)
    def forward(self, x, curr_epoch):
        # 1
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        x = F.max_pool2d(x, 2, 2)
        # 2
        x = F.relu(self.conv3(x))
        x = F.relu(self.conv4(x))
        x = F.max_pool2d(x, 2, 2)
        # 3
        x = x.view(-1, 4*4*128)
        x = F.relu(self.fc1(x))
        x = self.smd1(x, curr_epoch)
        x = F.relu(self.fc2(x))
        x = self.smd2(x, curr_epoch)
        x = self.fc3(x)
        return x
    def record_acc(self, acc):
        self.smd1.record_acc(acc)
        self.smd2.record_acc(acc)

# Initialize Model
model = Net_MNIST().to(device)

# define loss function and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=learning_rate)

# Train model
# train_loss_list, train_acc_list, test_loss_list, test_acc_list = Run('MNIST', 'SMD')

# %%
# plot('MNIST', 'SMD', exp_num)

# %%
class Net_CIFAR10_Drop(nn.Module):
    def __init__(self):
        super(Net_CIFAR10_Drop, self).__init__()
        self.conv1 = nn.Conv2d(3, 64, 3, 1, padding=1)
        self.conv2 = nn.Conv2d(64, 64, 3, 1)
        self.conv3 = nn.Conv2d(64, 128, 3, 1)
        self.conv4 = nn.Conv2d(128, 128, 3, 1)
        self.fc1 = nn.Linear(5*5*128, 4096)
        self.fc2 = nn.Linear(4096, 4096)
        self.fc3 = nn.Linear(4096, 10)
        # self.smd1 = SMD(p=dropout_prob, total_epoch=total_epoch, k=top_k)
        # self.smd2 = SMD(p=dropout_prob, total_epoch=total_epoch, k=top_k)
        self.drop1 = nn.Dropout(dropout_prob)
        self.drop2 = nn.Dropout(dropout_prob)

    def forward(self, x, curr_epoch):
        # 1
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        x = F.max_pool2d(x, 2, 2)
        # 2
        x = F.relu(self.conv3(x))
        x = F.relu(self.conv4(x))
        x = F.max_pool2d(x, 2, 2)
        # 3
        x = x.view(-1, 5*5*128)
        x = F.relu(self.fc1(x))
        x = self.drop1(x)
        x = F.relu(self.fc2(x))
        x = self.drop2(x)
        x = self.fc3(x)
        return x
    def record_acc(self, acc):
        self.smd1.record_acc(acc)
        self.smd2.record_acc(acc)
        
# Initialize model
model = Net_CIFAR10_Drop().to(device)

# Define loss function and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=learning_rate)

# Train model
train_loss_list, train_acc_list, test_loss_list, test_acc_list = Run('CIFAR10', 'Drop')
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Finished loading CIFAR10 dataset
# Epoch  1 | Train Loss: 0.0566 | Train Accuracy: 14.7 | Val Loss: 0.2262 | Val Accuracy: 16.06
# Epoch  2 | Train Loss: 0.0476 | Train Accuracy: 30.67 | Val Loss: 0.1891 | Val Accuracy: 31.52
# Epoch  3 | Train Loss: 0.0415 | Train Accuracy: 39.23 | Val Loss: 0.1645 | Val Accuracy: 39.43
# Epoch  4 | Train Loss: 0.0379 | Train Accuracy: 44.63 | Val Loss: 0.1503 | Val Accuracy: 45.21
# Epoch  5 | Train Loss: 0.0352 | Train Accuracy: 48.82 | Val Loss: 0.1399 | Val Accuracy: 49.2
# Epoch  6 | Train Loss: 0.0329 | Train Accuracy: 52.92 | Val Loss: 0.1301 | Val Accuracy: 53.2
# Epoch  7 | Train Loss: 0.0306 | Train Accuracy: 56.41 | Val Loss: 0.1220 | Val Accuracy: 56.27
# Epoch  8 | Train Loss: 0.0285 | Train Accuracy: 59.56 | Val Loss: 0.1147 | Val Accuracy: 59.97
# Epoch  9 | Train Loss: 0.0264 | Train Accuracy: 62.72 | Val Loss: 0.1079 | Val Accuracy: 61.91
# Epoch 10 | Train Loss: 0.0247 | Train Accuracy: 65.37 | Val Loss: 0.1014 | Val Accuracy: 64.6
# Epoch 11 | Train Loss: 0.0230 | Train Accuracy: 67.77 | Val Loss: 0.0969 | Val Accuracy: 65.95
# Epoch 12 | Train Loss: 0.0214 | Train Accuracy: 69.93 | Val Loss: 0.0927 | Val Accuracy: 67.84
# Epoch 13 | Train Loss: 0.0199 | Train Accuracy: 72.25 | Val Loss: 0.0888 | Val Accuracy: 69.12
# Epoch 14 | Train Loss: 0.0183 | Train Accuracy: 74.86 | Val Loss: 0.0857 | Val Accuracy: 70.35
# Epoch 15 | Train Loss: 0.0168 | Train Accuracy: 76.59 | Val Loss: 0.0838 | Val Accuracy: 71.24
# Epoch 16 | Train Loss: 0.0152 | Train Accuracy: 78.65 | Val Loss: 0.0822 | Val Accuracy: 72.28
# Epoch 17 | Train Loss: 0.0138 | Train Accuracy: 80.64 | Val Loss: 0.0797 | Val Accuracy: 73.3
# Epoch 18 | Train Loss: 0.0122 | Train Accuracy: 83.02 | Val Loss: 0.0788 | Val Accuracy: 74.27
# Epoch 19 | Train Loss: 0.0108 | Train Accuracy: 84.87 | Val Loss: 0.0806 | Val Accuracy: 74.12
# Epoch 20 | Train Loss: 0.0093 | Train Accuracy: 86.88 | Val Loss: 0.0810 | Val Accuracy: 74.4
# Epoch 21 | Train Loss: 0.0081 | Train Accuracy: 88.5 | Val Loss: 0.0833 | Val Accuracy: 74.98
# Epoch 22 | Train Loss: 0.0069 | Train Accuracy: 90.45 | Val Loss: 0.0846 | Val Accuracy: 75.39
# Epoch 23 | Train Loss: 0.0059 | Train Accuracy: 91.75 | Val Loss: 0.0879 | Val Accuracy: 75.36
# Epoch 24 | Train Loss: 0.0050 | Train Accuracy: 93.03 | Val Loss: 0.0911 | Val Accuracy: 75.19
# Epoch 25 | Train Loss: 0.0042 | Train Accuracy: 94.19 | Val Loss: 0.0957 | Val Accuracy: 75.44
# Epoch 26 | Train Loss: 0.0038 | Train Accuracy: 94.76 | Val Loss: 0.0972 | Val Accuracy: 75.75
# Epoch 27 | Train Loss: 0.0032 | Train Accuracy: 95.67 | Val Loss: 0.1014 | Val Accuracy: 75.66
# Epoch 28 | Train Loss: 0.0028 | Train Accuracy: 96.14 | Val Loss: 0.1030 | Val Accuracy: 75.75
# Epoch 29 | Train Loss: 0.0024 | Train Accuracy: 96.53 | Val Loss: 0.1060 | Val Accuracy: 76.39
# Epoch 30 | Train Loss: 0.0020 | Train Accuracy: 97.26 | Val Loss: 0.1113 | Val Accuracy: 76.18
# Epoch 31 | Train Loss: 0.0020 | Train Accuracy: 97.29 | Val Loss: 0.1128 | Val Accuracy: 76.19
# Epoch 32 | Train Loss: 0.0018 | Train Accuracy: 97.6 | Val Loss: 0.1146 | Val Accuracy: 76.16
# Epoch 33 | Train Loss: 0.0016 | Train Accuracy: 97.92 | Val Loss: 0.1161 | Val Accuracy: 76.15
# Epoch 34 | Train Loss: 0.0014 | Train Accuracy: 98.16 | Val Loss: 0.1174 | Val Accuracy: 76.46
# Epoch 35 | Train Loss: 0.0014 | Train Accuracy: 98.08 | Val Loss: 0.1198 | Val Accuracy: 76.14
# Epoch 36 | Train Loss: 0.0012 | Train Accuracy: 98.34 | Val Loss: 0.1211 | Val Accuracy: 76.43
# Epoch 37 | Train Loss: 0.0012 | Train Accuracy: 98.43 | Val Loss: 0.1224 | Val Accuracy: 76.27
# Epoch 38 | Train Loss: 0.0010 | Train Accuracy: 98.64 | Val Loss: 0.1235 | Val Accuracy: 76.63
# Epoch 39 | Train Loss: 0.0010 | Train Accuracy: 98.74 | Val Loss: 0.1303 | Val Accuracy: 76.27
# Epoch 40 | Train Loss: 0.0010 | Train Accuracy: 98.65 | Val Loss: 0.1298 | Val Accuracy: 76.5
# Epoch 41 | Train Loss: 0.0009 | Train Accuracy: 98.93 | Val Loss: 0.1281 | Val Accuracy: 76.75
# Epoch 42 | Train Loss: 0.0008 | Train Accuracy: 98.91 | Val Loss: 0.1303 | Val Accuracy: 76.54
# Epoch 43 | Train Loss: 0.0008 | Train Accuracy: 98.98 | Val Loss: 0.1288 | Val Accuracy: 76.52
# Epoch 44 | Train Loss: 0.0007 | Train Accuracy: 99.11 | Val Loss: 0.1319 | Val Accuracy: 76.59
# Epoch 45 | Train Loss: 0.0007 | Train Accuracy: 99.1 | Val Loss: 0.1337 | Val Accuracy: 76.8
# Epoch 46 | Train Loss: 0.0007 | Train Accuracy: 99.13 | Val Loss: 0.1346 | Val Accuracy: 76.3
# Epoch 47 | Train Loss: 0.0006 | Train Accuracy: 99.21 | Val Loss: 0.1332 | Val Accuracy: 76.74
# Epoch 48 | Train Loss: 0.0006 | Train Accuracy: 99.27 | Val Loss: 0.1362 | Val Accuracy: 76.96
# Epoch 49 | Train Loss: 0.0006 | Train Accuracy: 99.17 | Val Loss: 0.1375 | Val Accuracy: 76.55
# Epoch 50 | Train Loss: 0.0005 | Train Accuracy: 99.31 | Val Loss: 0.1398 | Val Accuracy: 76.72
# Epoch 51 | Train Loss: 0.0006 | Train Accuracy: 99.22 | Val Loss: 0.1382 | Val Accuracy: 76.65
# Epoch 52 | Train Loss: 0.0005 | Train Accuracy: 99.35 | Val Loss: 0.1383 | Val Accuracy: 76.59
# Epoch 53 | Train Loss: 0.0004 | Train Accuracy: 99.47 | Val Loss: 0.1391 | Val Accuracy: 77.12
# Epoch 54 | Train Loss: 0.0005 | Train Accuracy: 99.29 | Val Loss: 0.1417 | Val Accuracy: 76.9
# Epoch 55 | Train Loss: 0.0005 | Train Accuracy: 99.37 | Val Loss: 0.1431 | Val Accuracy: 76.69
# Epoch 56 | Train Loss: 0.0005 | Train Accuracy: 99.31 | Val Loss: 0.1454 | Val Accuracy: 76.73
# Epoch 57 | Train Loss: 0.0004 | Train Accuracy: 99.38 | Val Loss: 0.1466 | Val Accuracy: 76.65
# Epoch 58 | Train Loss: 0.0005 | Train Accuracy: 99.38 | Val Loss: 0.1454 | Val Accuracy: 76.53
# Epoch 59 | Train Loss: 0.0005 | Train Accuracy: 99.37 | Val Loss: 0.1451 | Val Accuracy: 76.51
# Epoch 60 | Train Loss: 0.0004 | Train Accuracy: 99.44 | Val Loss: 0.1485 | Val Accuracy: 76.34
# Epoch 61 | Train Loss: 0.0004 | Train Accuracy: 99.49 | Val Loss: 0.1441 | Val Accuracy: 76.86
# Epoch 62 | Train Loss: 0.0003 | Train Accuracy: 99.52 | Val Loss: 0.1449 | Val Accuracy: 76.98
# Epoch 63 | Train Loss: 0.0003 | Train Accuracy: 99.63 | Val Loss: 0.1476 | Val Accuracy: 77.22
# Epoch 64 | Train Loss: 0.0004 | Train Accuracy: 99.48 | Val Loss: 0.1519 | Val Accuracy: 76.97
# Epoch 65 | Train Loss: 0.0004 | Train Accuracy: 99.5 | Val Loss: 0.1480 | Val Accuracy: 76.91
# Epoch 66 | Train Loss: 0.0003 | Train Accuracy: 99.57 | Val Loss: 0.1521 | Val Accuracy: 76.84
# Epoch 67 | Train Loss: 0.0003 | Train Accuracy: 99.56 | Val Loss: 0.1505 | Val Accuracy: 76.95
# Epoch 68 | Train Loss: 0.0003 | Train Accuracy: 99.6 | Val Loss: 0.1527 | Val Accuracy: 77.07
# Epoch 69 | Train Loss: 0.0003 | Train Accuracy: 99.65 | Val Loss: 0.1542 | Val Accuracy: 76.88
# Epoch 70 | Train Loss: 0.0003 | Train Accuracy: 99.66 | Val Loss: 0.1520 | Val Accuracy: 76.68
# Epoch 71 | Train Loss: 0.0003 | Train Accuracy: 99.67 | Val Loss: 0.1546 | Val Accuracy: 77.19
# Epoch 72 | Train Loss: 0.0003 | Train Accuracy: 99.63 | Val Loss: 0.1548 | Val Accuracy: 76.84
# Epoch 73 | Train Loss: 0.0003 | Train Accuracy: 99.59 | Val Loss: 0.1565 | Val Accuracy: 76.96
# Epoch 74 | Train Loss: 0.0003 | Train Accuracy: 99.67 | Val Loss: 0.1558 | Val Accuracy: 76.89
# Epoch 75 | Train Loss: 0.0003 | Train Accuracy: 99.67 | Val Loss: 0.1554 | Val Accuracy: 77.19
# Epoch 76 | Train Loss: 0.0003 | Train Accuracy: 99.67 | Val Loss: 0.1586 | Val Accuracy: 76.99
# Epoch 77 | Train Loss: 0.0003 | Train Accuracy: 99.64 | Val Loss: 0.1540 | Val Accuracy: 77.28
# Epoch 78 | Train Loss: 0.0003 | Train Accuracy: 99.64 | Val Loss: 0.1572 | Val Accuracy: 76.94
# Epoch 79 | Train Loss: 0.0002 | Train Accuracy: 99.73 | Val Loss: 0.1586 | Val Accuracy: 76.85
# Epoch 80 | Train Loss: 0.0002 | Train Accuracy: 99.72 | Val Loss: 0.1572 | Val Accuracy: 77.0
# Epoch 81 | Train Loss: 0.0003 | Train Accuracy: 99.69 | Val Loss: 0.1573 | Val Accuracy: 76.89
# Epoch 82 | Train Loss: 0.0002 | Train Accuracy: 99.76 | Val Loss: 0.1585 | Val Accuracy: 76.94
# Epoch 83 | Train Loss: 0.0002 | Train Accuracy: 99.78 | Val Loss: 0.1575 | Val Accuracy: 77.19
# Epoch 84 | Train Loss: 0.0002 | Train Accuracy: 99.72 | Val Loss: 0.1588 | Val Accuracy: 77.4
# Epoch 85 | Train Loss: 0.0002 | Train Accuracy: 99.65 | Val Loss: 0.1585 | Val Accuracy: 77.15
# Epoch 86 | Train Loss: 0.0002 | Train Accuracy: 99.75 | Val Loss: 0.1599 | Val Accuracy: 77.36
# Epoch 87 | Train Loss: 0.0002 | Train Accuracy: 99.73 | Val Loss: 0.1600 | Val Accuracy: 77.6
# Epoch 88 | Train Loss: 0.0002 | Train Accuracy: 99.72 | Val Loss: 0.1606 | Val Accuracy: 77.26
# Epoch 89 | Train Loss: 0.0002 | Train Accuracy: 99.77 | Val Loss: 0.1598 | Val Accuracy: 77.31
# Epoch 90 | Train Loss: 0.0002 | Train Accuracy: 99.72 | Val Loss: 0.1612 | Val Accuracy: 77.17
# Epoch 91 | Train Loss: 0.0002 | Train Accuracy: 99.78 | Val Loss: 0.1602 | Val Accuracy: 77.58
# Epoch 92 | Train Loss: 0.0002 | Train Accuracy: 99.78 | Val Loss: 0.1600 | Val Accuracy: 77.35
# Epoch 93 | Train Loss: 0.0002 | Train Accuracy: 99.78 | Val Loss: 0.1660 | Val Accuracy: 77.3
# Epoch 94 | Train Loss: 0.0002 | Train Accuracy: 99.74 | Val Loss: 0.1641 | Val Accuracy: 76.87
# Epoch 95 | Train Loss: 0.0001 | Train Accuracy: 99.82 | Val Loss: 0.1638 | Val Accuracy: 76.58
# Epoch 96 | Train Loss: 0.0001 | Train Accuracy: 99.79 | Val Loss: 0.1661 | Val Accuracy: 76.91
# Epoch 97 | Train Loss: 0.0002 | Train Accuracy: 99.76 | Val Loss: 0.1641 | Val Accuracy: 77.08
# Epoch 98 | Train Loss: 0.0002 | Train Accuracy: 99.77 | Val Loss: 0.1641 | Val Accuracy: 77.34
# Epoch 99 | Train Loss: 0.0002 | Train Accuracy: 99.75 | Val Loss: 0.1663 | Val Accuracy: 77.14
# Epoch 100 | Train Loss: 0.0002 | Train Accuracy: 99.78 | Val Loss: 0.1633 | Val Accuracy: 77.16
# Epoch 101 | Train Loss: 0.0002 | Train Accuracy: 99.79 | Val Loss: 0.1642 | Val Accuracy: 77.48
# Epoch 102 | Train Loss: 0.0001 | Train Accuracy: 99.87 | Val Loss: 0.1662 | Val Accuracy: 77.75
# Epoch 103 | Train Loss: 0.0002 | Train Accuracy: 99.82 | Val Loss: 0.1658 | Val Accuracy: 77.38
# Epoch 104 | Train Loss: 0.0002 | Train Accuracy: 99.78 | Val Loss: 0.1686 | Val Accuracy: 76.83
# Epoch 105 | Train Loss: 0.0002 | Train Accuracy: 99.8 | Val Loss: 0.1680 | Val Accuracy: 77.34
# Epoch 106 | Train Loss: 0.0001 | Train Accuracy: 99.8 | Val Loss: 0.1657 | Val Accuracy: 77.45
# Epoch 107 | Train Loss: 0.0002 | Train Accuracy: 99.8 | Val Loss: 0.1674 | Val Accuracy: 77.28
# Epoch 108 | Train Loss: 0.0001 | Train Accuracy: 99.83 | Val Loss: 0.1640 | Val Accuracy: 77.37
# Epoch 109 | Train Loss: 0.0002 | Train Accuracy: 99.8 | Val Loss: 0.1679 | Val Accuracy: 77.47
# Epoch 110 | Train Loss: 0.0002 | Train Accuracy: 99.76 | Val Loss: 0.1666 | Val Accuracy: 77.4
# Epoch 111 | Train Loss: 0.0002 | Train Accuracy: 99.78 | Val Loss: 0.1675 | Val Accuracy: 77.01
# Epoch 112 | Train Loss: 0.0002 | Train Accuracy: 99.82 | Val Loss: 0.1652 | Val Accuracy: 77.48
# Epoch 113 | Train Loss: 0.0001 | Train Accuracy: 99.87 | Val Loss: 0.1665 | Val Accuracy: 76.93
# Epoch 114 | Train Loss: 0.0001 | Train Accuracy: 99.88 | Val Loss: 0.1696 | Val Accuracy: 77.49
# Epoch 115 | Train Loss: 0.0002 | Train Accuracy: 99.8 | Val Loss: 0.1702 | Val Accuracy: 77.25
# Epoch 116 | Train Loss: 0.0001 | Train Accuracy: 99.83 | Val Loss: 0.1699 | Val Accuracy: 77.16
# Epoch 117 | Train Loss: 0.0001 | Train Accuracy: 99.87 | Val Loss: 0.1696 | Val Accuracy: 77.38
# Epoch 118 | Train Loss: 0.0001 | Train Accuracy: 99.87 | Val Loss: 0.1730 | Val Accuracy: 77.56
# Epoch 119 | Train Loss: 0.0001 | Train Accuracy: 99.87 | Val Loss: 0.1714 | Val Accuracy: 77.44
# Epoch 120 | Train Loss: 0.0001 | Train Accuracy: 99.83 | Val Loss: 0.1749 | Val Accuracy: 77.3
# Epoch 121 | Train Loss: 0.0001 | Train Accuracy: 99.84 | Val Loss: 0.1721 | Val Accuracy: 77.47
# Epoch 122 | Train Loss: 0.0001 | Train Accuracy: 99.91 | Val Loss: 0.1715 | Val Accuracy: 77.78
# Epoch 123 | Train Loss: 0.0001 | Train Accuracy: 99.89 | Val Loss: 0.1760 | Val Accuracy: 77.49
# Epoch 124 | Train Loss: 0.0001 | Train Accuracy: 99.85 | Val Loss: 0.1763 | Val Accuracy: 77.49
# Epoch 125 | Train Loss: 0.0001 | Train Accuracy: 99.85 | Val Loss: 0.1741 | Val Accuracy: 77.32
# Epoch 126 | Train Loss: 0.0001 | Train Accuracy: 99.85 | Val Loss: 0.1782 | Val Accuracy: 76.81
# Epoch 127 | Train Loss: 0.0001 | Train Accuracy: 99.86 | Val Loss: 0.1770 | Val Accuracy: 76.97
# Epoch 128 | Train Loss: 0.0002 | Train Accuracy: 99.8 | Val Loss: 0.1781 | Val Accuracy: 76.88
# Epoch 129 | Train Loss: 0.0001 | Train Accuracy: 99.86 | Val Loss: 0.1746 | Val Accuracy: 77.12
# Epoch 130 | Train Loss: 0.0002 | Train Accuracy: 99.85 | Val Loss: 0.1744 | Val Accuracy: 77.08
# Epoch 131 | Train Loss: 0.0001 | Train Accuracy: 99.88 | Val Loss: 0.1739 | Val Accuracy: 77.21
# Epoch 132 | Train Loss: 0.0001 | Train Accuracy: 99.82 | Val Loss: 0.1747 | Val Accuracy: 77.44
# Epoch 133 | Train Loss: 0.0001 | Train Accuracy: 99.86 | Val Loss: 0.1756 | Val Accuracy: 77.39
# Epoch 134 | Train Loss: 0.0001 | Train Accuracy: 99.85 | Val Loss: 0.1773 | Val Accuracy: 77.56
# Epoch 135 | Train Loss: 0.0001 | Train Accuracy: 99.86 | Val Loss: 0.1811 | Val Accuracy: 76.97
# Epoch 136 | Train Loss: 0.0001 | Train Accuracy: 99.86 | Val Loss: 0.1760 | Val Accuracy: 77.12
# Epoch 137 | Train Loss: 0.0001 | Train Accuracy: 99.87 | Val Loss: 0.1760 | Val Accuracy: 77.38
# Epoch 138 | Train Loss: 0.0001 | Train Accuracy: 99.87 | Val Loss: 0.1789 | Val Accuracy: 76.83
# Epoch 139 | Train Loss: 0.0001 | Train Accuracy: 99.87 | Val Loss: 0.1776 | Val Accuracy: 76.74
# Epoch 140 | Train Loss: 0.0001 | Train Accuracy: 99.88 | Val Loss: 0.1772 | Val Accuracy: 77.15
# Epoch 141 | Train Loss: 0.0001 | Train Accuracy: 99.87 | Val Loss: 0.1770 | Val Accuracy: 76.8
# Epoch 142 | Train Loss: 0.0001 | Train Accuracy: 99.86 | Val Loss: 0.1756 | Val Accuracy: 77.06
# Epoch 143 | Train Loss: 0.0001 | Train Accuracy: 99.85 | Val Loss: 0.1769 | Val Accuracy: 77.15
# Epoch 144 | Train Loss: 0.0001 | Train Accuracy: 99.89 | Val Loss: 0.1754 | Val Accuracy: 77.16
# Epoch 145 | Train Loss: 0.0001 | Train Accuracy: 99.85 | Val Loss: 0.1759 | Val Accuracy: 77.13
# Epoch 146 | Train Loss: 0.0001 | Train Accuracy: 99.87 | Val Loss: 0.1760 | Val Accuracy: 77.37
# Epoch 147 | Train Loss: 0.0001 | Train Accuracy: 99.88 | Val Loss: 0.1758 | Val Accuracy: 76.73
# Epoch 148 | Train Loss: 0.0001 | Train Accuracy: 99.88 | Val Loss: 0.1774 | Val Accuracy: 77.12
# Epoch 149 | Train Loss: 0.0001 | Train Accuracy: 99.91 | Val Loss: 0.1791 | Val Accuracy: 77.26
# Epoch 150 | Train Loss: 0.0001 | Train Accuracy: 99.92 | Val Loss: 0.1816 | Val Accuracy: 77.57
# Epoch 151 | Train Loss: 0.0001 | Train Accuracy: 99.91 | Val Loss: 0.1784 | Val Accuracy: 77.64
# Epoch 152 | Train Loss: 0.0001 | Train Accuracy: 99.9 | Val Loss: 0.1811 | Val Accuracy: 77.28
# Epoch 153 | Train Loss: 0.0001 | Train Accuracy: 99.89 | Val Loss: 0.1828 | Val Accuracy: 77.23
# Epoch 154 | Train Loss: 0.0001 | Train Accuracy: 99.91 | Val Loss: 0.1805 | Val Accuracy: 77.05
# Epoch 155 | Train Loss: 0.0001 | Train Accuracy: 99.89 | Val Loss: 0.1865 | Val Accuracy: 77.17
# Epoch 156 | Train Loss: 0.0001 | Train Accuracy: 99.92 | Val Loss: 0.1861 | Val Accuracy: 76.9
# Epoch 157 | Train Loss: 0.0001 | Train Accuracy: 99.91 | Val Loss: 0.1799 | Val Accuracy: 76.93
# Epoch 158 | Train Loss: 0.0001 | Train Accuracy: 99.92 | Val Loss: 0.1818 | Val Accuracy: 77.22
# Epoch 159 | Train Loss: 0.0001 | Train Accuracy: 99.92 | Val Loss: 0.1804 | Val Accuracy: 77.2
# Epoch 160 | Train Loss: 0.0001 | Train Accuracy: 99.93 | Val Loss: 0.1842 | Val Accuracy: 77.34
# Epoch 161 | Train Loss: 0.0001 | Train Accuracy: 99.88 | Val Loss: 0.1856 | Val Accuracy: 77.23
# Epoch 162 | Train Loss: 0.0001 | Train Accuracy: 99.89 | Val Loss: 0.1834 | Val Accuracy: 77.33
# Epoch 163 | Train Loss: 0.0001 | Train Accuracy: 99.94 | Val Loss: 0.1826 | Val Accuracy: 77.64
# Epoch 164 | Train Loss: 0.0001 | Train Accuracy: 99.91 | Val Loss: 0.1814 | Val Accuracy: 77.28
# Epoch 165 | Train Loss: 0.0001 | Train Accuracy: 99.93 | Val Loss: 0.1781 | Val Accuracy: 77.7
# Epoch 166 | Train Loss: 0.0001 | Train Accuracy: 99.9 | Val Loss: 0.1799 | Val Accuracy: 77.37
# Epoch 167 | Train Loss: 0.0001 | Train Accuracy: 99.89 | Val Loss: 0.1796 | Val Accuracy: 77.27
# Epoch 168 | Train Loss: 0.0001 | Train Accuracy: 99.93 | Val Loss: 0.1827 | Val Accuracy: 77.65
# Epoch 169 | Train Loss: 0.0000 | Train Accuracy: 99.94 | Val Loss: 0.1828 | Val Accuracy: 77.39
# Epoch 170 | Train Loss: 0.0001 | Train Accuracy: 99.92 | Val Loss: 0.1852 | Val Accuracy: 77.25
# Epoch 171 | Train Loss: 0.0001 | Train Accuracy: 99.92 | Val Loss: 0.1857 | Val Accuracy: 77.37
# Epoch 172 | Train Loss: 0.0001 | Train Accuracy: 99.92 | Val Loss: 0.1844 | Val Accuracy: 77.68
# Epoch 173 | Train Loss: 0.0001 | Train Accuracy: 99.9 | Val Loss: 0.1852 | Val Accuracy: 77.54
# Epoch 174 | Train Loss: 0.0001 | Train Accuracy: 99.92 | Val Loss: 0.1854 | Val Accuracy: 77.16
# Epoch 175 | Train Loss: 0.0001 | Train Accuracy: 99.89 | Val Loss: 0.1886 | Val Accuracy: 77.39
# Epoch 176 | Train Loss: 0.0001 | Train Accuracy: 99.89 | Val Loss: 0.1872 | Val Accuracy: 77.27
# Epoch 177 | Train Loss: 0.0000 | Train Accuracy: 99.94 | Val Loss: 0.1849 | Val Accuracy: 77.32
# Epoch 178 | Train Loss: 0.0001 | Train Accuracy: 99.93 | Val Loss: 0.1860 | Val Accuracy: 77.45
# Epoch 179 | Train Loss: 0.0001 | Train Accuracy: 99.85 | Val Loss: 0.1842 | Val Accuracy: 77.67
# Epoch 180 | Train Loss: 0.0001 | Train Accuracy: 99.88 | Val Loss: 0.1830 | Val Accuracy: 77.21
# Epoch 181 | Train Loss: 0.0001 | Train Accuracy: 99.93 | Val Loss: 0.1816 | Val Accuracy: 77.67
# Epoch 182 | Train Loss: 0.0001 | Train Accuracy: 99.89 | Val Loss: 0.1845 | Val Accuracy: 77.07
# Epoch 183 | Train Loss: 0.0001 | Train Accuracy: 99.92 | Val Loss: 0.1846 | Val Accuracy: 77.37
# Epoch 184 | Train Loss: 0.0001 | Train Accuracy: 99.91 | Val Loss: 0.1847 | Val Accuracy: 77.32
# Epoch 185 | Train Loss: 0.0000 | Train Accuracy: 99.93 | Val Loss: 0.1871 | Val Accuracy: 77.36
# Epoch 186 | Train Loss: 0.0001 | Train Accuracy: 99.89 | Val Loss: 0.1902 | Val Accuracy: 77.03
# Epoch 187 | Train Loss: 0.0001 | Train Accuracy: 99.87 | Val Loss: 0.1895 | Val Accuracy: 77.22
# Epoch 188 | Train Loss: 0.0000 | Train Accuracy: 99.93 | Val Loss: 0.1904 | Val Accuracy: 77.26
# Epoch 189 | Train Loss: 0.0001 | Train Accuracy: 99.92 | Val Loss: 0.1903 | Val Accuracy: 77.39
# Epoch 190 | Train Loss: 0.0001 | Train Accuracy: 99.92 | Val Loss: 0.1869 | Val Accuracy: 77.36
# Epoch 191 | Train Loss: 0.0001 | Train Accuracy: 99.89 | Val Loss: 0.1889 | Val Accuracy: 77.18
# Epoch 192 | Train Loss: 0.0001 | Train Accuracy: 99.93 | Val Loss: 0.1874 | Val Accuracy: 77.29
# Epoch 193 | Train Loss: 0.0000 | Train Accuracy: 99.94 | Val Loss: 0.1853 | Val Accuracy: 77.46
# Epoch 194 | Train Loss: 0.0001 | Train Accuracy: 99.94 | Val Loss: 0.1870 | Val Accuracy: 77.08
# Epoch 195 | Train Loss: 0.0001 | Train Accuracy: 99.93 | Val Loss: 0.1889 | Val Accuracy: 77.25
# Epoch 196 | Train Loss: 0.0001 | Train Accuracy: 99.89 | Val Loss: 0.1913 | Val Accuracy: 76.95
# Epoch 197 | Train Loss: 0.0001 | Train Accuracy: 99.91 | Val Loss: 0.1934 | Val Accuracy: 77.02
# Epoch 198 | Train Loss: 0.0001 | Train Accuracy: 99.91 | Val Loss: 0.1902 | Val Accuracy: 77.31
# Epoch 199 | Train Loss: 0.0001 | Train Accuracy: 99.91 | Val Loss: 0.1904 | Val Accuracy: 77.54
# Epoch 200 | Train Loss: 0.0000 | Train Accuracy: 99.95 | Val Loss: 0.1877 | Val Accuracy: 77.49

# %%
plot('CIFAR10', 'SMD', exp_num)
