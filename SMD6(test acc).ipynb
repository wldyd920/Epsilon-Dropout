# %% [markdown]
# train acc로 evaluation method 전환.
# 각 batch 마다, top k masks에 저장.
# exploit시에 top k masks에서 가져오기.
#
# batch별 train, test 구현.
# test acc로 evaluation method 전환.

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torchvision.datasets import MNIST
from torchvision.datasets import CIFAR10
from torchvision.datasets import CIFAR100
from torchvision.datasets import FashionMNIST
from torchvision.transforms import ToTensor
import matplotlib.pyplot as plt
from torchvision import datasets, transforms
from torch.nn import functional as F
import sys
import os
import math
import random

# device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device = torch.device('cuda')
print(device)
# Out:
# cuda

# %%
# Hyperparameter configurations
exp_num = -1     # To save the result, change every time. -1 to not save.
total_epoch = 100
learning_rate = 0.01
dropout_prob = 0.5
top_k = 10
if exp_num!=-1: os.mkdir(f'./Result{exp_num}')

# %%
def dataset_MNIST():
  transform = transforms.Compose([transforms.ToTensor(),
                                  transforms.Normalize((0.1307,), (0.3081,))])
  train_dataset = MNIST(root='../data', train=True, download=True, transform=transform)
  test_dataset = MNIST(root='../data', train=False, download=True, transform=transform)
  train_loader = DataLoader(train_dataset, batch_size=60, shuffle=True, drop_last=True)
  test_loader = DataLoader(test_dataset, batch_size=12, shuffle=True, drop_last=True)
  return train_loader, test_loader

def dataset_FMNIST():
  transform = transforms.Compose([transforms.ToTensor(),
                                  transforms.Normalize((0.2860,), (0.3530,))])
  train_dataset = FashionMNIST(root='../data', train=True, download=True, transform=transform)
  test_dataset = FashionMNIST(root='../data', train=False, download=True, transform=transform)
  train_loader = DataLoader(train_dataset, batch_size=60, shuffle=True, drop_last=True)
  test_loader = DataLoader(test_dataset, batch_size=12, shuffle=True, drop_last=True)
  return train_loader, test_loader

def dataset_CIFAR10():
  transform = transforms.Compose([transforms.ToTensor(),
                                  transforms.Normalize((0.4914, 0.4822, 0.4465), (0.247, 0.243, 0.261))])
  train_dataset = CIFAR10(root='../data', train=True, download=True, transform=transform)
  test_dataset = CIFAR10(root='../data', train=False, download=True, transform=transform)
  train_loader = DataLoader(train_dataset, batch_size=60, shuffle=True, drop_last=True)
  test_loader = DataLoader(test_dataset, batch_size=12, shuffle=True, drop_last=True)
  return train_loader, test_loader

def dataset_CIFAR100():
  transform = transforms.Compose([transforms.ToTensor(),
                                  transforms.Normalize((0.5071, 0.4867, 0.4408), (0.2675, 0.2565, 0.2761))])
  train_dataset = CIFAR100(root='../data', train=True, download=True, transform=transform)
  test_dataset = CIFAR100(root='../data', train=False, download=True, transform=transform)
  train_loader = DataLoader(train_dataset, batch_size=60, shuffle=True, drop_last=True)
  test_loader = DataLoader(test_dataset, batch_size=12, shuffle=True, drop_last=True)
  return train_loader, test_loader

# %%
def Run(dataset, method):
    # Choose dataset
    if dataset=='MNIST': train_loader, test_loader = dataset_MNIST()
    elif dataset=='FMNIST': train_loader, test_loader = dataset_FMNIST()
    elif dataset=='CIFAR10': train_loader, test_loader = dataset_CIFAR10()
    elif dataset=='CIFAR100': train_loader, test_loader = dataset_CIFAR100()
    print(f'Finished loading {dataset} dataset')
    
    # Save log
    if exp_num!=-1:
        sys.stdout = open(f'./Result{exp_num}/{dataset}_{method}.txt', 'w')
        sys.stdout = open(f'./Result{exp_num}/{dataset}_{method}.txt', 'a')
    
    train_acc_list = []
    test_acc_list = []
    train_loss_list = []
    test_loss_list = []
    for epoch in range(total_epoch):
        
        train_loss, train_correct, test_loss, test_correct = 0,0,0,0
        train_iter = iter(train_loader)
        test_iter = iter(test_loader)
        # print(len(train_loader), len(test_loader))
        for i in range(len(train_loader)):
            # Train
            model.train()
            (data, target) = next(train_iter)
            data, target = data.to(device), target.to(device)
            optimizer.zero_grad()
            output = model(data, epoch)
            loss = criterion(output, target)
            loss.backward()
            optimizer.step()
            train_loss += loss.item()
            train_correct += (output.argmax(1) == target).sum().item()
            
            # Test
            model.eval()
            with torch.no_grad():
                (data, target) = next(test_iter)
                data, target = data.to(device), target.to(device)
                output = model(data, epoch)
                loss = criterion(output, target)
                test_loss += loss.item()
                test_correct += (output.argmax(1) == target).sum().item()
                model.record_acc((output.argmax(1) == target).sum().item())  # EVAL MASK!!!

        train_loss /= len(train_loader.dataset)
        train_accuracy = train_correct / len(train_loader.dataset)
        train_acc_list.append(train_accuracy)
        train_loss_list.append(train_loss) 

        test_loss /= len(test_loader.dataset)
        test_accuracy = test_correct / len(test_loader.dataset)
        test_acc_list.append(test_accuracy)
        test_loss_list.append(test_loss)

        # Show Result
        print(f'Epoch {epoch + 1:2d} | '
            f'Train Loss: {train_loss:.4f} | Train Accuracy: {round(train_accuracy*100, 2)} | '
            f'Test Loss: {test_loss:.4f} | Test Accuracy: {round(test_accuracy*100, 2)}')
    return train_loss_list, train_acc_list, test_loss_list, test_acc_list


# 그래프
def plot(dataset, method, exp_num):
    figname = f"[{dataset}] {method}  #{exp_num}.svg"
    plt.figure(figsize=(10, 6), dpi=100)
    plt.plot(train_acc_list, label='Train_acc')
    plt.plot(test_acc_list, label='Test_acc')
    plt.plot(train_loss_list, label='Train_loss')
    plt.plot(test_loss_list, label='Test_loss')
    plt.legend()
    plt.title('Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    if exp_num != -1 : plt.savefig(f'./Result{exp_num}/'+figname, format='svg')
    plt.show()

# %%
class SMD(nn.Module):
    def __init__(self, p=0.5, total_epoch=10, k=1):
        super(SMD, self).__init__()
        self.p = p
        self.total_epoch = total_epoch
        self.topk_masks = []
        self.mask = None
        self.accs = []
        self.k = k

    def forward(self, x, curr_epoch):
        if self.training:
            if curr_epoch <= (self.total_epoch/2):
                self.mask = (torch.rand_like(x) > self.p).float().to(device)
                x = x * self.mask / (1 - self.p)
                x = x.to(device)
                return x
            elif curr_epoch > (self.total_epoch/2):
                self.mask = random.choice(self.topk_masks)
                x = x * self.mask / (1 - self.p)
                return x
        if not self.training:
            return x

    def record_acc(self, acc):
        if len(self.topk_masks) < self.k:
            self.topk_masks.append(self.mask)
            self.accs.append(acc)
        elif len(self.topk_masks) >= self.k:    
            lowest = min(self.accs)
            if acc > lowest:
                lowest_idx = self.accs.index(lowest)
                self.topk_masks.pop(lowest_idx)
                self.accs.pop(lowest_idx)
                self.topk_masks.append(self.mask)
                self.accs.append(acc)

# %%
class Net_CIFAR10(nn.Module):
    def __init__(self):
        super(Net_CIFAR10, self).__init__()
        self.conv1 = nn.Conv2d(3, 64, 3, 1, padding=1)
        self.conv2 = nn.Conv2d(64, 64, 3, 1)
        self.conv3 = nn.Conv2d(64, 128, 3, 1)
        self.conv4 = nn.Conv2d(128, 128, 3, 1)
        self.fc1 = nn.Linear(5*5*128, 4096)
        self.fc2 = nn.Linear(4096, 4096)
        self.fc3 = nn.Linear(4096, 10)
        self.smd1 = SMD(p=dropout_prob, total_epoch=total_epoch, k=top_k)
        self.smd2 = SMD(p=dropout_prob, total_epoch=total_epoch, k=top_k)

    def forward(self, x, curr_epoch):
        # 1
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        x = F.max_pool2d(x, 2, 2)
        # 2
        x = F.relu(self.conv3(x))
        x = F.relu(self.conv4(x))
        x = F.max_pool2d(x, 2, 2)
        # 3
        x = x.view(-1, 5*5*128)
        x = F.relu(self.fc1(x))
        x = self.smd1(x, curr_epoch)
        x = F.relu(self.fc2(x))
        x = self.smd2(x, curr_epoch)
        x = self.fc3(x)
        return x
    def record_acc(self, acc):
        self.smd1.record_acc(acc)
        self.smd2.record_acc(acc)
        
# Initialize model
model = Net_CIFAR10().to(device)

# Define loss function and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=learning_rate)

# Train model
train_loss_list, train_acc_list, test_loss_list, test_acc_list = Run('CIFAR10', 'SMD')
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Finished loading CIFAR10 dataset
# Epoch  1 | Train Loss: 0.0375 | Train Accuracy: 14.89 | Test Loss: 0.1870 | Test Accuracy: 15.4
# Epoch  2 | Train Loss: 0.0329 | Train Accuracy: 28.29 | Test Loss: 0.1616 | Test Accuracy: 29.85
# Epoch  3 | Train Loss: 0.0291 | Train Accuracy: 36.69 | Test Loss: 0.1421 | Test Accuracy: 38.37
# Epoch  4 | Train Loss: 0.0264 | Train Accuracy: 42.33 | Test Loss: 0.1285 | Test Accuracy: 43.84
# Epoch  5 | Train Loss: 0.0247 | Train Accuracy: 46.19 | Test Loss: 0.1210 | Test Accuracy: 47.11
# Epoch  6 | Train Loss: 0.0233 | Train Accuracy: 49.54 | Test Loss: 0.1139 | Test Accuracy: 50.15
# Epoch  7 | Train Loss: 0.0220 | Train Accuracy: 52.71 | Test Loss: 0.1078 | Test Accuracy: 53.56
# Epoch  8 | Train Loss: 0.0208 | Train Accuracy: 55.11 | Test Loss: 0.1025 | Test Accuracy: 56.22
# Epoch  9 | Train Loss: 0.0197 | Train Accuracy: 58.21 | Test Loss: 0.0971 | Test Accuracy: 58.12
# Epoch 10 | Train Loss: 0.0186 | Train Accuracy: 60.55 | Test Loss: 0.0927 | Test Accuracy: 60.96
# Epoch 11 | Train Loss: 0.0177 | Train Accuracy: 62.75 | Test Loss: 0.0884 | Test Accuracy: 62.67
# Epoch 12 | Train Loss: 0.0166 | Train Accuracy: 65.22 | Test Loss: 0.0847 | Test Accuracy: 64.23
# Epoch 13 | Train Loss: 0.0156 | Train Accuracy: 67.16 | Test Loss: 0.0811 | Test Accuracy: 66.01
# Epoch 14 | Train Loss: 0.0147 | Train Accuracy: 69.03 | Test Loss: 0.0778 | Test Accuracy: 67.49
# Epoch 15 | Train Loss: 0.0137 | Train Accuracy: 71.4 | Test Loss: 0.0749 | Test Accuracy: 68.55
# Epoch 16 | Train Loss: 0.0128 | Train Accuracy: 73.3 | Test Loss: 0.0726 | Test Accuracy: 69.77
# Epoch 17 | Train Loss: 0.0119 | Train Accuracy: 75.3 | Test Loss: 0.0705 | Test Accuracy: 71.14
# Epoch 18 | Train Loss: 0.0111 | Train Accuracy: 76.9 | Test Loss: 0.0681 | Test Accuracy: 71.99
# Epoch 19 | Train Loss: 0.0102 | Train Accuracy: 78.79 | Test Loss: 0.0674 | Test Accuracy: 72.86
# Epoch 20 | Train Loss: 0.0093 | Train Accuracy: 80.38 | Test Loss: 0.0657 | Test Accuracy: 73.46
# Epoch 21 | Train Loss: 0.0085 | Train Accuracy: 82.2 | Test Loss: 0.0648 | Test Accuracy: 74.16
# Epoch 22 | Train Loss: 0.0077 | Train Accuracy: 83.93 | Test Loss: 0.0663 | Test Accuracy: 73.98
# Epoch 23 | Train Loss: 0.0069 | Train Accuracy: 85.56 | Test Loss: 0.0660 | Test Accuracy: 74.78
# Epoch 24 | Train Loss: 0.0061 | Train Accuracy: 87.11 | Test Loss: 0.0668 | Test Accuracy: 75.24
# Epoch 25 | Train Loss: 0.0055 | Train Accuracy: 88.44 | Test Loss: 0.0681 | Test Accuracy: 75.29
# Epoch 26 | Train Loss: 0.0048 | Train Accuracy: 89.88 | Test Loss: 0.0710 | Test Accuracy: 75.3
# Epoch 27 | Train Loss: 0.0042 | Train Accuracy: 91.1 | Test Loss: 0.0716 | Test Accuracy: 75.7
# Epoch 28 | Train Loss: 0.0037 | Train Accuracy: 92.33 | Test Loss: 0.0746 | Test Accuracy: 75.82
# Epoch 29 | Train Loss: 0.0033 | Train Accuracy: 93.02 | Test Loss: 0.0759 | Test Accuracy: 75.78
# Epoch 30 | Train Loss: 0.0028 | Train Accuracy: 94.11 | Test Loss: 0.0765 | Test Accuracy: 75.8
# Epoch 31 | Train Loss: 0.0025 | Train Accuracy: 94.65 | Test Loss: 0.0802 | Test Accuracy: 76.03
# Epoch 32 | Train Loss: 0.0022 | Train Accuracy: 95.25 | Test Loss: 0.0831 | Test Accuracy: 76.22
# Epoch 33 | Train Loss: 0.0020 | Train Accuracy: 95.87 | Test Loss: 0.0836 | Test Accuracy: 76.07
# Epoch 34 | Train Loss: 0.0018 | Train Accuracy: 96.42 | Test Loss: 0.0857 | Test Accuracy: 76.36
# Epoch 35 | Train Loss: 0.0016 | Train Accuracy: 96.68 | Test Loss: 0.0886 | Test Accuracy: 76.28
# Epoch 36 | Train Loss: 0.0015 | Train Accuracy: 96.95 | Test Loss: 0.0894 | Test Accuracy: 76.64
# Epoch 37 | Train Loss: 0.0014 | Train Accuracy: 97.08 | Test Loss: 0.0902 | Test Accuracy: 76.54
# Epoch 38 | Train Loss: 0.0012 | Train Accuracy: 97.51 | Test Loss: 0.0918 | Test Accuracy: 76.52
# Epoch 39 | Train Loss: 0.0012 | Train Accuracy: 97.56 | Test Loss: 0.0949 | Test Accuracy: 76.75
# Epoch 40 | Train Loss: 0.0011 | Train Accuracy: 97.6 | Test Loss: 0.0952 | Test Accuracy: 76.98
# Epoch 41 | Train Loss: 0.0010 | Train Accuracy: 97.97 | Test Loss: 0.0960 | Test Accuracy: 76.73
# Epoch 42 | Train Loss: 0.0009 | Train Accuracy: 98.16 | Test Loss: 0.0961 | Test Accuracy: 76.92
# Epoch 43 | Train Loss: 0.0009 | Train Accuracy: 98.06 | Test Loss: 0.0984 | Test Accuracy: 76.72
# Epoch 44 | Train Loss: 0.0008 | Train Accuracy: 98.49 | Test Loss: 0.1003 | Test Accuracy: 76.87
# Epoch 45 | Train Loss: 0.0007 | Train Accuracy: 98.56 | Test Loss: 0.1008 | Test Accuracy: 76.78
# Epoch 46 | Train Loss: 0.0008 | Train Accuracy: 98.4 | Test Loss: 0.1042 | Test Accuracy: 77.24
# Epoch 47 | Train Loss: 0.0007 | Train Accuracy: 98.57 | Test Loss: 0.1027 | Test Accuracy: 77.0
# Epoch 48 | Train Loss: 0.0007 | Train Accuracy: 98.62 | Test Loss: 0.1036 | Test Accuracy: 76.98
# Epoch 49 | Train Loss: 0.0006 | Train Accuracy: 98.72 | Test Loss: 0.1054 | Test Accuracy: 77.07
# Epoch 50 | Train Loss: 0.0006 | Train Accuracy: 98.79 | Test Loss: 0.1061 | Test Accuracy: 77.05
# Epoch 51 | Train Loss: 0.0006 | Train Accuracy: 98.82 | Test Loss: 0.1058 | Test Accuracy: 77.09
# Epoch 52 | Train Loss: 0.0005 | Train Accuracy: 98.98 | Test Loss: 0.1067 | Test Accuracy: 77.43
# Epoch 53 | Train Loss: 0.0005 | Train Accuracy: 99.08 | Test Loss: 0.1096 | Test Accuracy: 77.07
# Epoch 54 | Train Loss: 0.0005 | Train Accuracy: 99.0 | Test Loss: 0.1087 | Test Accuracy: 77.16
# Epoch 55 | Train Loss: 0.0004 | Train Accuracy: 99.1 | Test Loss: 0.1103 | Test Accuracy: 77.24
# Epoch 56 | Train Loss: 0.0004 | Train Accuracy: 99.21 | Test Loss: 0.1109 | Test Accuracy: 77.59
# Epoch 57 | Train Loss: 0.0004 | Train Accuracy: 99.09 | Test Loss: 0.1121 | Test Accuracy: 77.33
# Epoch 58 | Train Loss: 0.0004 | Train Accuracy: 99.2 | Test Loss: 0.1140 | Test Accuracy: 77.43
# Epoch 59 | Train Loss: 0.0004 | Train Accuracy: 99.23 | Test Loss: 0.1148 | Test Accuracy: 77.27
# Epoch 60 | Train Loss: 0.0003 | Train Accuracy: 99.31 | Test Loss: 0.1136 | Test Accuracy: 77.42
# Epoch 61 | Train Loss: 0.0003 | Train Accuracy: 99.4 | Test Loss: 0.1145 | Test Accuracy: 77.13
# Epoch 62 | Train Loss: 0.0003 | Train Accuracy: 99.25 | Test Loss: 0.1174 | Test Accuracy: 77.43
# Epoch 63 | Train Loss: 0.0004 | Train Accuracy: 99.29 | Test Loss: 0.1182 | Test Accuracy: 77.15
# Epoch 64 | Train Loss: 0.0003 | Train Accuracy: 99.35 | Test Loss: 0.1166 | Test Accuracy: 77.0
# Epoch 65 | Train Loss: 0.0003 | Train Accuracy: 99.42 | Test Loss: 0.1166 | Test Accuracy: 77.43
# Epoch 66 | Train Loss: 0.0003 | Train Accuracy: 99.34 | Test Loss: 0.1167 | Test Accuracy: 77.36
# Epoch 67 | Train Loss: 0.0003 | Train Accuracy: 99.39 | Test Loss: 0.1205 | Test Accuracy: 77.19
# Epoch 68 | Train Loss: 0.0003 | Train Accuracy: 99.43 | Test Loss: 0.1202 | Test Accuracy: 77.17
# Epoch 69 | Train Loss: 0.0002 | Train Accuracy: 99.5 | Test Loss: 0.1206 | Test Accuracy: 77.19
# Epoch 70 | Train Loss: 0.0003 | Train Accuracy: 99.46 | Test Loss: 0.1224 | Test Accuracy: 77.09
# Epoch 71 | Train Loss: 0.0003 | Train Accuracy: 99.47 | Test Loss: 0.1213 | Test Accuracy: 77.36
# Epoch 72 | Train Loss: 0.0002 | Train Accuracy: 99.47 | Test Loss: 0.1235 | Test Accuracy: 77.52
# Epoch 73 | Train Loss: 0.0002 | Train Accuracy: 99.58 | Test Loss: 0.1205 | Test Accuracy: 77.57
# Epoch 74 | Train Loss: 0.0002 | Train Accuracy: 99.49 | Test Loss: 0.1210 | Test Accuracy: 77.68
# Epoch 75 | Train Loss: 0.0002 | Train Accuracy: 99.58 | Test Loss: 0.1230 | Test Accuracy: 77.7
# Epoch 76 | Train Loss: 0.0002 | Train Accuracy: 99.55 | Test Loss: 0.1233 | Test Accuracy: 77.44
# Epoch 77 | Train Loss: 0.0002 | Train Accuracy: 99.5 | Test Loss: 0.1243 | Test Accuracy: 77.67
# Epoch 78 | Train Loss: 0.0002 | Train Accuracy: 99.57 | Test Loss: 0.1250 | Test Accuracy: 77.63
# Epoch 79 | Train Loss: 0.0002 | Train Accuracy: 99.56 | Test Loss: 0.1262 | Test Accuracy: 77.05
# Epoch 80 | Train Loss: 0.0002 | Train Accuracy: 99.55 | Test Loss: 0.1270 | Test Accuracy: 77.09
# Epoch 81 | Train Loss: 0.0002 | Train Accuracy: 99.47 | Test Loss: 0.1265 | Test Accuracy: 77.37
# Epoch 82 | Train Loss: 0.0002 | Train Accuracy: 99.56 | Test Loss: 0.1269 | Test Accuracy: 77.34
# Epoch 83 | Train Loss: 0.0002 | Train Accuracy: 99.62 | Test Loss: 0.1248 | Test Accuracy: 77.4
# Epoch 84 | Train Loss: 0.0002 | Train Accuracy: 99.65 | Test Loss: 0.1268 | Test Accuracy: 77.55
# Epoch 85 | Train Loss: 0.0002 | Train Accuracy: 99.67 | Test Loss: 0.1269 | Test Accuracy: 77.82
# Epoch 86 | Train Loss: 0.0002 | Train Accuracy: 99.66 | Test Loss: 0.1284 | Test Accuracy: 77.78
# Epoch 87 | Train Loss: 0.0002 | Train Accuracy: 99.59 | Test Loss: 0.1278 | Test Accuracy: 77.59
# Epoch 88 | Train Loss: 0.0001 | Train Accuracy: 99.67 | Test Loss: 0.1282 | Test Accuracy: 77.87
# Epoch 89 | Train Loss: 0.0002 | Train Accuracy: 99.64 | Test Loss: 0.1306 | Test Accuracy: 77.86
# Epoch 90 | Train Loss: 0.0002 | Train Accuracy: 99.62 | Test Loss: 0.1300 | Test Accuracy: 77.66
# Epoch 91 | Train Loss: 0.0002 | Train Accuracy: 99.66 | Test Loss: 0.1301 | Test Accuracy: 77.47
# Epoch 92 | Train Loss: 0.0001 | Train Accuracy: 99.69 | Test Loss: 0.1292 | Test Accuracy: 77.82
# Epoch 93 | Train Loss: 0.0001 | Train Accuracy: 99.73 | Test Loss: 0.1333 | Test Accuracy: 77.56
# Epoch 94 | Train Loss: 0.0001 | Train Accuracy: 99.67 | Test Loss: 0.1321 | Test Accuracy: 77.9
# Epoch 95 | Train Loss: 0.0002 | Train Accuracy: 99.64 | Test Loss: 0.1339 | Test Accuracy: 77.95
# Epoch 96 | Train Loss: 0.0001 | Train Accuracy: 99.7 | Test Loss: 0.1323 | Test Accuracy: 77.92
# Epoch 97 | Train Loss: 0.0002 | Train Accuracy: 99.65 | Test Loss: 0.1331 | Test Accuracy: 78.05
# Epoch 98 | Train Loss: 0.0002 | Train Accuracy: 99.66 | Test Loss: 0.1347 | Test Accuracy: 77.82
# Epoch 99 | Train Loss: 0.0001 | Train Accuracy: 99.71 | Test Loss: 0.1354 | Test Accuracy: 77.85
# Epoch 100 | Train Loss: 0.0002 | Train Accuracy: 99.63 | Test Loss: 0.1335 | Test Accuracy: 77.64

# %%
plot('CIFAR10', 'SMD', exp_num)

# %%
class Net_CIFAR100(nn.Module):
    def __init__(self):
        super(Net_CIFAR100, self).__init__()
        self.conv1 = nn.Conv2d(3, 64, 3, 1, padding=1)
        self.conv2 = nn.Conv2d(64, 64, 3, 1)
        self.conv3 = nn.Conv2d(64, 128, 3, 1)
        self.conv4 = nn.Conv2d(128, 128, 3, 1)
        self.fc1 = nn.Linear(5*5*128, 4096)
        self.fc2 = nn.Linear(4096, 4096)
        self.fc3 = nn.Linear(4096, 100)
        self.smd1 = SMD(p=dropout_prob, total_epoch=total_epoch, k=top_k)
        self.smd2 = SMD(p=dropout_prob, total_epoch=total_epoch, k=top_k)

    def forward(self, x, curr_epoch):
        # 1
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        x = F.max_pool2d(x, 2, 2)
        # 2
        x = F.relu(self.conv3(x))
        x = F.relu(self.conv4(x))
        x = F.max_pool2d(x, 2, 2)
        # 3
        x = x.view(-1, 5*5*128)
        x = F.relu(self.fc1(x))
        x = self.smd1(x, curr_epoch)
        x = F.relu(self.fc2(x))
        x = self.smd2(x, curr_epoch)
        x = self.fc3(x)
        return x
    def record_acc(self, acc):
        self.smd1.record_acc(acc)
        self.smd2.record_acc(acc)
        
# Initialize model
model = Net_CIFAR100().to(device)

# Define loss function and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=learning_rate)

# Train model
train_loss_list, train_acc_list, test_loss_list, test_acc_list = Run('CIFAR100', 'SMD')
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Finished loading CIFAR100 dataset
# Epoch  1 | Train Loss: 0.0767 | Train Accuracy: 1.08 | Test Loss: 0.3835 | Test Accuracy: 1.14
# Epoch  2 | Train Loss: 0.0766 | Train Accuracy: 1.29 | Test Loss: 0.3830 | Test Accuracy: 1.6
# Epoch  3 | Train Loss: 0.0744 | Train Accuracy: 3.06 | Test Loss: 0.3706 | Test Accuracy: 3.54
# Epoch  4 | Train Loss: 0.0692 | Train Accuracy: 6.33 | Test Loss: 0.3422 | Test Accuracy: 7.52
# Epoch  5 | Train Loss: 0.0658 | Train Accuracy: 9.39 | Test Loss: 0.3256 | Test Accuracy: 10.06
# Epoch  6 | Train Loss: 0.0635 | Train Accuracy: 11.44 | Test Loss: 0.3133 | Test Accuracy: 12.53
# Epoch  7 | Train Loss: 0.0614 | Train Accuracy: 13.49 | Test Loss: 0.3030 | Test Accuracy: 14.83
# Epoch  8 | Train Loss: 0.0595 | Train Accuracy: 15.58 | Test Loss: 0.2930 | Test Accuracy: 17.19
# Epoch  9 | Train Loss: 0.0576 | Train Accuracy: 17.62 | Test Loss: 0.2845 | Test Accuracy: 19.02
# Epoch 10 | Train Loss: 0.0557 | Train Accuracy: 19.96 | Test Loss: 0.2754 | Test Accuracy: 21.75
# Epoch 11 | Train Loss: 0.0540 | Train Accuracy: 21.32 | Test Loss: 0.2680 | Test Accuracy: 22.75
# Epoch 12 | Train Loss: 0.0522 | Train Accuracy: 23.51 | Test Loss: 0.2602 | Test Accuracy: 24.52
# Epoch 13 | Train Loss: 0.0507 | Train Accuracy: 25.21 | Test Loss: 0.2533 | Test Accuracy: 26.05
# Epoch 14 | Train Loss: 0.0491 | Train Accuracy: 27.0 | Test Loss: 0.2466 | Test Accuracy: 28.01
# Epoch 15 | Train Loss: 0.0476 | Train Accuracy: 28.53 | Test Loss: 0.2409 | Test Accuracy: 29.19
# Epoch 16 | Train Loss: 0.0461 | Train Accuracy: 30.5 | Test Loss: 0.2353 | Test Accuracy: 30.2
# Epoch 17 | Train Loss: 0.0446 | Train Accuracy: 32.18 | Test Loss: 0.2304 | Test Accuracy: 31.5
# Epoch 18 | Train Loss: 0.0431 | Train Accuracy: 34.1 | Test Loss: 0.2259 | Test Accuracy: 32.78
# Epoch 19 | Train Loss: 0.0417 | Train Accuracy: 35.63 | Test Loss: 0.2215 | Test Accuracy: 33.82
# Epoch 20 | Train Loss: 0.0402 | Train Accuracy: 37.57 | Test Loss: 0.2173 | Test Accuracy: 34.92
# Epoch 21 | Train Loss: 0.0387 | Train Accuracy: 39.5 | Test Loss: 0.2150 | Test Accuracy: 35.83
# Epoch 22 | Train Loss: 0.0373 | Train Accuracy: 41.14 | Test Loss: 0.2118 | Test Accuracy: 36.48
# Epoch 23 | Train Loss: 0.0356 | Train Accuracy: 43.54 | Test Loss: 0.2086 | Test Accuracy: 37.5
# Epoch 24 | Train Loss: 0.0340 | Train Accuracy: 45.46 | Test Loss: 0.2066 | Test Accuracy: 37.89
# Epoch 25 | Train Loss: 0.0323 | Train Accuracy: 47.75 | Test Loss: 0.2043 | Test Accuracy: 38.76
# Epoch 26 | Train Loss: 0.0308 | Train Accuracy: 49.86 | Test Loss: 0.2030 | Test Accuracy: 39.2
# Epoch 27 | Train Loss: 0.0291 | Train Accuracy: 51.89 | Test Loss: 0.2015 | Test Accuracy: 40.04
# Epoch 28 | Train Loss: 0.0273 | Train Accuracy: 54.59 | Test Loss: 0.2015 | Test Accuracy: 40.14
# Epoch 29 | Train Loss: 0.0255 | Train Accuracy: 56.92 | Test Loss: 0.2024 | Test Accuracy: 40.17
# Epoch 30 | Train Loss: 0.0238 | Train Accuracy: 59.59 | Test Loss: 0.2029 | Test Accuracy: 40.39
# Epoch 31 | Train Loss: 0.0220 | Train Accuracy: 61.93 | Test Loss: 0.2030 | Test Accuracy: 40.77
# Epoch 32 | Train Loss: 0.0203 | Train Accuracy: 64.55 | Test Loss: 0.2037 | Test Accuracy: 40.83
# Epoch 33 | Train Loss: 0.0186 | Train Accuracy: 66.94 | Test Loss: 0.2063 | Test Accuracy: 40.99
# Epoch 34 | Train Loss: 0.0173 | Train Accuracy: 69.16 | Test Loss: 0.2079 | Test Accuracy: 41.53
# Epoch 35 | Train Loss: 0.0156 | Train Accuracy: 71.83 | Test Loss: 0.2096 | Test Accuracy: 41.67
# Epoch 36 | Train Loss: 0.0143 | Train Accuracy: 74.06 | Test Loss: 0.2121 | Test Accuracy: 41.46
# Epoch 37 | Train Loss: 0.0130 | Train Accuracy: 76.18 | Test Loss: 0.2165 | Test Accuracy: 41.62
# Epoch 38 | Train Loss: 0.0118 | Train Accuracy: 78.02 | Test Loss: 0.2182 | Test Accuracy: 42.02
# Epoch 39 | Train Loss: 0.0108 | Train Accuracy: 79.76 | Test Loss: 0.2207 | Test Accuracy: 42.15
# Epoch 40 | Train Loss: 0.0098 | Train Accuracy: 81.62 | Test Loss: 0.2243 | Test Accuracy: 41.5
# Epoch 41 | Train Loss: 0.0088 | Train Accuracy: 83.44 | Test Loss: 0.2283 | Test Accuracy: 42.39
# Epoch 42 | Train Loss: 0.0083 | Train Accuracy: 84.47 | Test Loss: 0.2305 | Test Accuracy: 41.83
# Epoch 43 | Train Loss: 0.0075 | Train Accuracy: 85.71 | Test Loss: 0.2337 | Test Accuracy: 42.03
# Epoch 44 | Train Loss: 0.0070 | Train Accuracy: 86.84 | Test Loss: 0.2355 | Test Accuracy: 42.28
# Epoch 45 | Train Loss: 0.0065 | Train Accuracy: 87.65 | Test Loss: 0.2404 | Test Accuracy: 41.78
# Epoch 46 | Train Loss: 0.0059 | Train Accuracy: 88.79 | Test Loss: 0.2406 | Test Accuracy: 42.69
# Epoch 47 | Train Loss: 0.0056 | Train Accuracy: 89.41 | Test Loss: 0.2464 | Test Accuracy: 41.89
# Epoch 48 | Train Loss: 0.0053 | Train Accuracy: 89.76 | Test Loss: 0.2482 | Test Accuracy: 41.79
# Epoch 49 | Train Loss: 0.0047 | Train Accuracy: 90.95 | Test Loss: 0.2480 | Test Accuracy: 42.04
# Epoch 50 | Train Loss: 0.0047 | Train Accuracy: 90.99 | Test Loss: 0.2524 | Test Accuracy: 42.42
# Epoch 51 | Train Loss: 0.0043 | Train Accuracy: 91.75 | Test Loss: 0.2530 | Test Accuracy: 42.43
# Epoch 52 | Train Loss: 0.0040 | Train Accuracy: 92.31 | Test Loss: 0.2560 | Test Accuracy: 42.28
# Epoch 53 | Train Loss: 0.0038 | Train Accuracy: 92.64 | Test Loss: 0.2577 | Test Accuracy: 42.54
# Epoch 54 | Train Loss: 0.0034 | Train Accuracy: 93.48 | Test Loss: 0.2591 | Test Accuracy: 42.91
# Epoch 55 | Train Loss: 0.0033 | Train Accuracy: 93.68 | Test Loss: 0.2606 | Test Accuracy: 42.52
# Epoch 56 | Train Loss: 0.0031 | Train Accuracy: 93.99 | Test Loss: 0.2612 | Test Accuracy: 43.12
# Epoch 57 | Train Loss: 0.0029 | Train Accuracy: 94.47 | Test Loss: 0.2642 | Test Accuracy: 43.19
# Epoch 58 | Train Loss: 0.0027 | Train Accuracy: 94.78 | Test Loss: 0.2676 | Test Accuracy: 43.03
# Epoch 59 | Train Loss: 0.0027 | Train Accuracy: 94.85 | Test Loss: 0.2688 | Test Accuracy: 42.91
# Epoch 60 | Train Loss: 0.0026 | Train Accuracy: 95.12 | Test Loss: 0.2712 | Test Accuracy: 43.2
# Epoch 61 | Train Loss: 0.0025 | Train Accuracy: 95.25 | Test Loss: 0.2719 | Test Accuracy: 42.56
# Epoch 62 | Train Loss: 0.0023 | Train Accuracy: 95.65 | Test Loss: 0.2716 | Test Accuracy: 43.45
# Epoch 63 | Train Loss: 0.0021 | Train Accuracy: 95.95 | Test Loss: 0.2776 | Test Accuracy: 42.79
# Epoch 64 | Train Loss: 0.0021 | Train Accuracy: 95.87 | Test Loss: 0.2794 | Test Accuracy: 43.28
# Epoch 65 | Train Loss: 0.0020 | Train Accuracy: 96.18 | Test Loss: 0.2820 | Test Accuracy: 43.12
# Epoch 66 | Train Loss: 0.0020 | Train Accuracy: 96.15 | Test Loss: 0.2802 | Test Accuracy: 43.57
# Epoch 67 | Train Loss: 0.0018 | Train Accuracy: 96.63 | Test Loss: 0.2825 | Test Accuracy: 43.14
# Epoch 68 | Train Loss: 0.0018 | Train Accuracy: 96.55 | Test Loss: 0.2857 | Test Accuracy: 43.03
# Epoch 69 | Train Loss: 0.0018 | Train Accuracy: 96.6 | Test Loss: 0.2860 | Test Accuracy: 43.31
# Epoch 70 | Train Loss: 0.0016 | Train Accuracy: 96.82 | Test Loss: 0.2851 | Test Accuracy: 42.97
# Epoch 71 | Train Loss: 0.0016 | Train Accuracy: 96.88 | Test Loss: 0.2897 | Test Accuracy: 42.67
# Epoch 72 | Train Loss: 0.0016 | Train Accuracy: 96.84 | Test Loss: 0.2905 | Test Accuracy: 43.24
# Epoch 73 | Train Loss: 0.0016 | Train Accuracy: 96.96 | Test Loss: 0.2902 | Test Accuracy: 42.96
# Epoch 74 | Train Loss: 0.0015 | Train Accuracy: 97.19 | Test Loss: 0.2914 | Test Accuracy: 43.24
# Epoch 75 | Train Loss: 0.0014 | Train Accuracy: 97.24 | Test Loss: 0.2922 | Test Accuracy: 43.31
# Epoch 76 | Train Loss: 0.0014 | Train Accuracy: 97.3 | Test Loss: 0.2918 | Test Accuracy: 43.33
# Epoch 77 | Train Loss: 0.0013 | Train Accuracy: 97.51 | Test Loss: 0.2953 | Test Accuracy: 43.31
# Epoch 78 | Train Loss: 0.0014 | Train Accuracy: 97.31 | Test Loss: 0.2931 | Test Accuracy: 43.4
# Epoch 79 | Train Loss: 0.0013 | Train Accuracy: 97.39 | Test Loss: 0.2962 | Test Accuracy: 43.29
# Epoch 80 | Train Loss: 0.0013 | Train Accuracy: 97.51 | Test Loss: 0.2951 | Test Accuracy: 43.3
# Epoch 81 | Train Loss: 0.0012 | Train Accuracy: 97.63 | Test Loss: 0.2939 | Test Accuracy: 43.54
# Epoch 82 | Train Loss: 0.0012 | Train Accuracy: 97.69 | Test Loss: 0.2988 | Test Accuracy: 43.06
# Epoch 83 | Train Loss: 0.0012 | Train Accuracy: 97.77 | Test Loss: 0.3036 | Test Accuracy: 43.38
# Epoch 84 | Train Loss: 0.0012 | Train Accuracy: 97.68 | Test Loss: 0.3014 | Test Accuracy: 43.35
# Epoch 85 | Train Loss: 0.0011 | Train Accuracy: 97.83 | Test Loss: 0.3016 | Test Accuracy: 43.53
# Epoch 86 | Train Loss: 0.0011 | Train Accuracy: 97.91 | Test Loss: 0.3000 | Test Accuracy: 43.68
# Epoch 87 | Train Loss: 0.0011 | Train Accuracy: 97.94 | Test Loss: 0.3019 | Test Accuracy: 43.56
# Epoch 88 | Train Loss: 0.0010 | Train Accuracy: 98.19 | Test Loss: 0.3029 | Test Accuracy: 43.51
# Epoch 89 | Train Loss: 0.0010 | Train Accuracy: 98.16 | Test Loss: 0.3038 | Test Accuracy: 43.6
# Epoch 90 | Train Loss: 0.0010 | Train Accuracy: 98.09 | Test Loss: 0.3037 | Test Accuracy: 43.12
# Epoch 91 | Train Loss: 0.0009 | Train Accuracy: 98.2 | Test Loss: 0.3055 | Test Accuracy: 43.51
# Epoch 92 | Train Loss: 0.0009 | Train Accuracy: 98.35 | Test Loss: 0.3074 | Test Accuracy: 43.45
# Epoch 93 | Train Loss: 0.0009 | Train Accuracy: 98.22 | Test Loss: 0.3126 | Test Accuracy: 43.3
# Epoch 94 | Train Loss: 0.0008 | Train Accuracy: 98.44 | Test Loss: 0.3180 | Test Accuracy: 43.3
# Epoch 95 | Train Loss: 0.0009 | Train Accuracy: 98.26 | Test Loss: 0.3161 | Test Accuracy: 43.31
# Epoch 96 | Train Loss: 0.0009 | Train Accuracy: 98.27 | Test Loss: 0.3133 | Test Accuracy: 43.61
# Epoch 97 | Train Loss: 0.0009 | Train Accuracy: 98.27 | Test Loss: 0.3084 | Test Accuracy: 44.04
# Epoch 98 | Train Loss: 0.0009 | Train Accuracy: 98.35 | Test Loss: 0.3080 | Test Accuracy: 43.71
# Epoch 99 | Train Loss: 0.0008 | Train Accuracy: 98.55 | Test Loss: 0.3062 | Test Accuracy: 43.63
# Epoch 100 | Train Loss: 0.0008 | Train Accuracy: 98.55 | Test Loss: 0.3127 | Test Accuracy: 43.44

# %%
plot('CIFAR100', 'SMD', exp_num)
