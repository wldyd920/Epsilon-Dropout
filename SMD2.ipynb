# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torchvision.datasets import FashionMNIST
from torchvision.transforms import ToTensor
import matplotlib.pyplot as plt
from torchvision import datasets, transforms
from torch.nn import functional as F
import math
import random

# device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device = torch.device('cuda')

# %%
def FMNIST_dataset():
    train_data = FashionMNIST(root='../data', train=True, download=True, transform=ToTensor())
    train_loader = DataLoader(train_data, batch_size=64, shuffle=True, drop_last=True)

    test_data = FashionMNIST(root='../data', train=False, download=True, transform=ToTensor())
    test_loader = DataLoader(test_data, batch_size=64, shuffle=True, drop_last=True)
    return train_loader, test_loader


def CIFAR10_dataset():
    transform = transforms.Compose(
        [transforms.ToTensor(),
        transforms.Normalize([0.4914, 0.4822, 0.4465], [0.2023, 0.1994, 0.2010])])
    train_set = datasets.CIFAR10(root='../data', train=True,
                                download=True, transform=transform)
    test_set = datasets.CIFAR10(root='../data', train=False,
                                download=True, transform=transform)
    
    batch_size = 64
    train_loader = torch.utils.data.DataLoader(train_set, batch_size=batch_size,
                                            shuffle=True, num_workers=2)
    test_loader = torch.utils.data.DataLoader(test_set, batch_size=batch_size,
                                            shuffle=False, num_workers=2)
    return train_loader, test_loader


def Run(dataset, model, optimizer, criterion, EPOCHS):
    if dataset == 'CIFAR-10': train_loader, test_loader = CIFAR10_dataset()
    elif dataset == 'FMNIST': train_loader, test_loader = FMNIST_dataset()
    
    train_acc_list = []
    test_acc_list = []
    train_loss_list = []
    test_loss_list = []
    for epoch in range(EPOCHS):
        # Train
        model.train()
        train_loss = 0
        train_correct = 0
        for i, (data, target) in enumerate(train_loader):
            data, target = data.to(device), target.to(device)
            optimizer.zero_grad()
            output = model(data)
            loss = criterion(output, target)
            loss.backward()
            optimizer.step()
            train_loss += loss.item()
            train_correct += (output.argmax(1) == target).sum().item()
            # batch_acc = (output.argmax(1) == target).sum().item()/len(target)
            
        train_loss /= len(train_loader.dataset)
        train_accuracy = train_correct / len(train_loader.dataset)
        train_acc_list.append(train_accuracy)
        train_loss_list.append(train_loss)
        
        # Test
        model.eval()
        test_loss = 0
        test_correct = 0
        with torch.no_grad():
            for data, target in test_loader:
                data, target = data.to(device), target.to(device)
                output = model(data)
                loss = criterion(output, target)
                test_loss += loss.item()
                test_correct += (output.argmax(1) == target).sum().item()
            model.record_loss(loss.item())
            test_loss /= len(test_loader.dataset)
            test_accuracy = test_correct / len(test_loader.dataset)
            test_acc_list.append(test_accuracy)
            test_loss_list.append(test_loss)
            
            
        
        # Show Result
        print(f'Epoch {epoch + 1:2d} | '
            f'Train Loss: {train_loss:.4f} | Train Accuracy: {round(train_accuracy*100, 2)} | '
            f'Test Loss: {test_loss:.4f} | Test Accuracy: {round(test_accuracy*100, 2)}')
    return train_loss_list, train_acc_list, test_loss_list, test_acc_list


def plot(method, dataset, exp_num, train_loss_list, train_acc_list, test_loss_list, test_acc_list, save=False):
    figname = f"{method} ({dataset}) #{exp_num}.png"
    plt.figure(figsize=(10, 6), dpi=100)
    plt.plot(train_acc_list, label='Train_acc')
    plt.plot(test_acc_list, label='Test_acc')
    plt.plot(train_loss_list, label='Train_loss')
    plt.plot(test_loss_list, label='Test_loss')
    plt.legend()
    plt.title('Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    if save: plt.savefig(figname)
    plt.show()

# %%
class MyDrop(nn.Module):
    def __init__(self, p=0.5, total_epoch=10, k=1):
        super(MyDrop, self).__init__()
        self.p = p
        self.total_epoch = total_epoch
        self.masks = []
        self.accs = []
        self.k = k
        self.mask_idx = 0

    def forward(self, x):
        if self.training:
            mask = (torch.rand_like(x) > self.p).float().to(device) 
            self.masks.append(mask)
            self.accs.append(99)
            x = x * mask / (1 - self.p)
            x = x.to(device)
            return x
       
        elif not self.training:
            topk_masks = sorted(list(enumerate(zip(self.masks, self.accs))), key=lambda x: x[1][1], reverse=False)[:self.k]
            self.mask_idx = random.choice(topk_masks)[0]
            mask = topk_masks[0][1][0]
            x = x * mask / (1 - self.p)
            return x

    def record_loss(self, loss):
        if not self.training:
            self.accs[self.mask_idx] = loss

# %%
class Net_FMNIST(nn.Module):
    def __init__(self):
        super().__init__()
        # Layers
        self.conv1 = nn.Conv2d(1, 16, kernel_size=3, padding=1)
        self.bn1 = nn.BatchNorm2d(16)

        self.conv2 = nn.Conv2d(16, 32, kernel_size=3, padding=1)
        self.bn2 = nn.BatchNorm2d(32)

        self.fc1 = nn.Linear(32 * 7 * 7, 128)
        self.bn3 = nn.BatchNorm1d(128)

        self.fc2 = nn.Linear(128, 10)

        # Materials
        self.drop1 = nn.Dropout(0.25)
        self.drop2 = nn.Dropout(0.5)
        self.edrop = MyDrop(p=dropout_prob, total_epoch=total_epoch, k=top_k)


    def forward(self, x):
        # [64, 1, 28, 28]

        x = self.conv1(x)     
        x = self.bn1(x)       
        x = F.relu(x)          
        x = F.max_pool2d(x, 2)

        x = self.conv2(x)     
        x = self.bn2(x)    
        x = F.relu(x)         
        x = F.max_pool2d(x, 2)

        x = x.view(-1, 32 * 7 * 7)
        x = self.fc1(x)
        x = self.bn3(x)
        x = self.edrop(x)
        x = F.relu(x)
        
        x = self.fc2(x)
        return x
    
    def record_loss(self, loss):
        self.edrop.record_loss(loss)

# %%
# Run (FMNIST)
dropout_prob = 0.5
top_k = 10
dataset = 'FMNIST'
FMNIST_EPOCHS = 100

model = Net_FMNIST().to(device)
optimizer = optim.Adam(model.parameters(), lr=0.001)
criterion = nn.CrossEntropyLoss()

train_loss_list, train_acc_list, test_loss_list, test_acc_list = Run(dataset, model, optimizer, criterion, FMNIST_EPOCHS)
# Out:
# Epoch  1 | Train Loss: 0.0065 | Train Accuracy: 85.88 | Test Loss: 0.0052 | Test Accuracy: 87.71
# Epoch  2 | Train Loss: 0.0044 | Train Accuracy: 89.83 | Test Loss: 0.0046 | Test Accuracy: 89.29
# Epoch  3 | Train Loss: 0.0039 | Train Accuracy: 90.94 | Test Loss: 0.0043 | Test Accuracy: 90.15
# Epoch  4 | Train Loss: 0.0035 | Train Accuracy: 91.79 | Test Loss: 0.0043 | Test Accuracy: 90.62
# Epoch  5 | Train Loss: 0.0033 | Train Accuracy: 92.37 | Test Loss: 0.0043 | Test Accuracy: 89.95
# Epoch  6 | Train Loss: 0.0030 | Train Accuracy: 92.75 | Test Loss: 0.0043 | Test Accuracy: 90.21
# Epoch  7 | Train Loss: 0.0029 | Train Accuracy: 93.14 | Test Loss: 0.0043 | Test Accuracy: 90.48
# Epoch  8 | Train Loss: 0.0027 | Train Accuracy: 93.53 | Test Loss: 0.0041 | Test Accuracy: 91.11
# Epoch  9 | Train Loss: 0.0026 | Train Accuracy: 93.97 | Test Loss: 0.0041 | Test Accuracy: 90.89
# Epoch 10 | Train Loss: 0.0024 | Train Accuracy: 94.19 | Test Loss: 0.0045 | Test Accuracy: 90.51
# Epoch 11 | Train Loss: 0.0023 | Train Accuracy: 94.45 | Test Loss: 0.0043 | Test Accuracy: 90.8
# Epoch 12 | Train Loss: 0.0022 | Train Accuracy: 94.69 | Test Loss: 0.0045 | Test Accuracy: 90.76
# Epoch 13 | Train Loss: 0.0021 | Train Accuracy: 94.98 | Test Loss: 0.0043 | Test Accuracy: 90.95
# Epoch 14 | Train Loss: 0.0020 | Train Accuracy: 95.23 | Test Loss: 0.0047 | Test Accuracy: 90.56
# Epoch 15 | Train Loss: 0.0020 | Train Accuracy: 95.35 | Test Loss: 0.0046 | Test Accuracy: 90.78
# Epoch 16 | Train Loss: 0.0018 | Train Accuracy: 95.5 | Test Loss: 0.0045 | Test Accuracy: 90.75
# Epoch 17 | Train Loss: 0.0018 | Train Accuracy: 95.75 | Test Loss: 0.0048 | Test Accuracy: 90.77
# Epoch 18 | Train Loss: 0.0018 | Train Accuracy: 95.7 | Test Loss: 0.0048 | Test Accuracy: 90.59
# Epoch 19 | Train Loss: 0.0017 | Train Accuracy: 95.95 | Test Loss: 0.0048 | Test Accuracy: 91.08
# Epoch 20 | Train Loss: 0.0016 | Train Accuracy: 96.09 | Test Loss: 0.0048 | Test Accuracy: 90.67
# Epoch 21 | Train Loss: 0.0015 | Train Accuracy: 96.19 | Test Loss: 0.0051 | Test Accuracy: 91.05
# Epoch 22 | Train Loss: 0.0015 | Train Accuracy: 96.36 | Test Loss: 0.0052 | Test Accuracy: 90.38
# Epoch 23 | Train Loss: 0.0015 | Train Accuracy: 96.43 | Test Loss: 0.0056 | Test Accuracy: 90.12
# Epoch 24 | Train Loss: 0.0014 | Train Accuracy: 96.63 | Test Loss: 0.0054 | Test Accuracy: 90.85
# Epoch 25 | Train Loss: 0.0014 | Train Accuracy: 96.63 | Test Loss: 0.0054 | Test Accuracy: 90.79
# Epoch 26 | Train Loss: 0.0014 | Train Accuracy: 96.65 | Test Loss: 0.0056 | Test Accuracy: 90.5
# Epoch 27 | Train Loss: 0.0013 | Train Accuracy: 96.84 | Test Loss: 0.0053 | Test Accuracy: 90.47
# Epoch 28 | Train Loss: 0.0012 | Train Accuracy: 97.06 | Test Loss: 0.0057 | Test Accuracy: 90.4
# Epoch 29 | Train Loss: 0.0012 | Train Accuracy: 97.04 | Test Loss: 0.0056 | Test Accuracy: 90.73
# Epoch 30 | Train Loss: 0.0012 | Train Accuracy: 97.04 | Test Loss: 0.0055 | Test Accuracy: 91.29
# Epoch 31 | Train Loss: 0.0011 | Train Accuracy: 97.22 | Test Loss: 0.0059 | Test Accuracy: 90.82
# Epoch 32 | Train Loss: 0.0012 | Train Accuracy: 97.21 | Test Loss: 0.0057 | Test Accuracy: 91.06
# Epoch 33 | Train Loss: 0.0011 | Train Accuracy: 97.22 | Test Loss: 0.0059 | Test Accuracy: 90.52
# Epoch 34 | Train Loss: 0.0011 | Train Accuracy: 97.35 | Test Loss: 0.0057 | Test Accuracy: 91.01
# Epoch 35 | Train Loss: 0.0011 | Train Accuracy: 97.43 | Test Loss: 0.0057 | Test Accuracy: 90.89
# Epoch 36 | Train Loss: 0.0010 | Train Accuracy: 97.51 | Test Loss: 0.0058 | Test Accuracy: 90.69
# Epoch 37 | Train Loss: 0.0010 | Train Accuracy: 97.46 | Test Loss: 0.0059 | Test Accuracy: 91.25
# Epoch 38 | Train Loss: 0.0010 | Train Accuracy: 97.55 | Test Loss: 0.0062 | Test Accuracy: 90.75
# Epoch 39 | Train Loss: 0.0010 | Train Accuracy: 97.56 | Test Loss: 0.0065 | Test Accuracy: 90.91
# Epoch 40 | Train Loss: 0.0010 | Train Accuracy: 97.69 | Test Loss: 0.0063 | Test Accuracy: 90.8
# Epoch 41 | Train Loss: 0.0010 | Train Accuracy: 97.68 | Test Loss: 0.0063 | Test Accuracy: 90.59
# Epoch 42 | Train Loss: 0.0009 | Train Accuracy: 97.7 | Test Loss: 0.0062 | Test Accuracy: 90.77
# Epoch 43 | Train Loss: 0.0009 | Train Accuracy: 97.67 | Test Loss: 0.0065 | Test Accuracy: 90.44
# Epoch 44 | Train Loss: 0.0009 | Train Accuracy: 97.84 | Test Loss: 0.0066 | Test Accuracy: 90.59
# Epoch 45 | Train Loss: 0.0009 | Train Accuracy: 97.87 | Test Loss: 0.0065 | Test Accuracy: 90.42
# Epoch 46 | Train Loss: 0.0009 | Train Accuracy: 97.82 | Test Loss: 0.0063 | Test Accuracy: 90.68
# Epoch 47 | Train Loss: 0.0008 | Train Accuracy: 97.9 | Test Loss: 0.0075 | Test Accuracy: 90.36
# Epoch 48 | Train Loss: 0.0009 | Train Accuracy: 97.8 | Test Loss: 0.0068 | Test Accuracy: 90.49
# Epoch 49 | Train Loss: 0.0009 | Train Accuracy: 97.85 | Test Loss: 0.0071 | Test Accuracy: 90.26
# Epoch 50 | Train Loss: 0.0008 | Train Accuracy: 97.89 | Test Loss: 0.0071 | Test Accuracy: 90.31
# Epoch 51 | Train Loss: 0.0008 | Train Accuracy: 97.97 | Test Loss: 0.0070 | Test Accuracy: 90.15
# Epoch 52 | Train Loss: 0.0008 | Train Accuracy: 98.06 | Test Loss: 0.0073 | Test Accuracy: 90.06
# Epoch 53 | Train Loss: 0.0008 | Train Accuracy: 98.0 | Test Loss: 0.0072 | Test Accuracy: 90.55
# Epoch 54 | Train Loss: 0.0008 | Train Accuracy: 98.01 | Test Loss: 0.0069 | Test Accuracy: 90.77
# Epoch 55 | Train Loss: 0.0008 | Train Accuracy: 98.13 | Test Loss: 0.0070 | Test Accuracy: 90.57
# Epoch 56 | Train Loss: 0.0008 | Train Accuracy: 98.09 | Test Loss: 0.0070 | Test Accuracy: 90.58
# Epoch 57 | Train Loss: 0.0008 | Train Accuracy: 98.06 | Test Loss: 0.0070 | Test Accuracy: 90.76
# Epoch 58 | Train Loss: 0.0008 | Train Accuracy: 98.07 | Test Loss: 0.0071 | Test Accuracy: 90.69
# Epoch 59 | Train Loss: 0.0007 | Train Accuracy: 98.25 | Test Loss: 0.0068 | Test Accuracy: 90.51
# Epoch 60 | Train Loss: 0.0007 | Train Accuracy: 98.17 | Test Loss: 0.0073 | Test Accuracy: 90.51
# Epoch 61 | Train Loss: 0.0007 | Train Accuracy: 98.22 | Test Loss: 0.0074 | Test Accuracy: 90.78
# Epoch 62 | Train Loss: 0.0007 | Train Accuracy: 98.26 | Test Loss: 0.0071 | Test Accuracy: 90.94
# Epoch 63 | Train Loss: 0.0007 | Train Accuracy: 98.25 | Test Loss: 0.0074 | Test Accuracy: 90.76
# Epoch 64 | Train Loss: 0.0007 | Train Accuracy: 98.21 | Test Loss: 0.0076 | Test Accuracy: 90.85
# Epoch 65 | Train Loss: 0.0007 | Train Accuracy: 98.23 | Test Loss: 0.0072 | Test Accuracy: 90.69
# Epoch 66 | Train Loss: 0.0007 | Train Accuracy: 98.28 | Test Loss: 0.0079 | Test Accuracy: 90.52
# Epoch 67 | Train Loss: 0.0007 | Train Accuracy: 98.38 | Test Loss: 0.0081 | Test Accuracy: 90.49
# Epoch 68 | Train Loss: 0.0007 | Train Accuracy: 98.3 | Test Loss: 0.0077 | Test Accuracy: 90.62
# Epoch 69 | Train Loss: 0.0007 | Train Accuracy: 98.42 | Test Loss: 0.0084 | Test Accuracy: 90.39
# Epoch 70 | Train Loss: 0.0007 | Train Accuracy: 98.33 | Test Loss: 0.0074 | Test Accuracy: 90.84
# Epoch 71 | Train Loss: 0.0007 | Train Accuracy: 98.39 | Test Loss: 0.0079 | Test Accuracy: 90.68
# Epoch 72 | Train Loss: 0.0007 | Train Accuracy: 98.34 | Test Loss: 0.0081 | Test Accuracy: 90.54
# Epoch 73 | Train Loss: 0.0007 | Train Accuracy: 98.38 | Test Loss: 0.0074 | Test Accuracy: 90.71
# Epoch 74 | Train Loss: 0.0007 | Train Accuracy: 98.41 | Test Loss: 0.0077 | Test Accuracy: 90.52
# Epoch 75 | Train Loss: 0.0006 | Train Accuracy: 98.4 | Test Loss: 0.0080 | Test Accuracy: 90.55
# Epoch 76 | Train Loss: 0.0006 | Train Accuracy: 98.47 | Test Loss: 0.0076 | Test Accuracy: 90.68
# Epoch 77 | Train Loss: 0.0006 | Train Accuracy: 98.42 | Test Loss: 0.0074 | Test Accuracy: 90.94
# Epoch 78 | Train Loss: 0.0006 | Train Accuracy: 98.5 | Test Loss: 0.0081 | Test Accuracy: 90.28
# Epoch 79 | Train Loss: 0.0006 | Train Accuracy: 98.46 | Test Loss: 0.0079 | Test Accuracy: 90.62
# Epoch 80 | Train Loss: 0.0006 | Train Accuracy: 98.55 | Test Loss: 0.0080 | Test Accuracy: 90.82
# Epoch 81 | Train Loss: 0.0007 | Train Accuracy: 98.38 | Test Loss: 0.0080 | Test Accuracy: 90.77
# Epoch 82 | Train Loss: 0.0006 | Train Accuracy: 98.41 | Test Loss: 0.0079 | Test Accuracy: 90.45
# Epoch 83 | Train Loss: 0.0006 | Train Accuracy: 98.49 | Test Loss: 0.0085 | Test Accuracy: 90.67
# Epoch 84 | Train Loss: 0.0006 | Train Accuracy: 98.57 | Test Loss: 0.0080 | Test Accuracy: 90.79
# Epoch 85 | Train Loss: 0.0007 | Train Accuracy: 98.38 | Test Loss: 0.0083 | Test Accuracy: 90.7
# Epoch 86 | Train Loss: 0.0006 | Train Accuracy: 98.59 | Test Loss: 0.0081 | Test Accuracy: 90.59
# Epoch 87 | Train Loss: 0.0006 | Train Accuracy: 98.61 | Test Loss: 0.0079 | Test Accuracy: 90.84
# Epoch 88 | Train Loss: 0.0006 | Train Accuracy: 98.47 | Test Loss: 0.0082 | Test Accuracy: 90.83
# Epoch 89 | Train Loss: 0.0006 | Train Accuracy: 98.59 | Test Loss: 0.0080 | Test Accuracy: 90.84
# Epoch 90 | Train Loss: 0.0005 | Train Accuracy: 98.72 | Test Loss: 0.0085 | Test Accuracy: 90.6
# Epoch 91 | Train Loss: 0.0005 | Train Accuracy: 98.66 | Test Loss: 0.0086 | Test Accuracy: 90.61
# Epoch 92 | Train Loss: 0.0006 | Train Accuracy: 98.53 | Test Loss: 0.0087 | Test Accuracy: 90.54
# Epoch 93 | Train Loss: 0.0005 | Train Accuracy: 98.64 | Test Loss: 0.0088 | Test Accuracy: 90.66
# Epoch 94 | Train Loss: 0.0006 | Train Accuracy: 98.54 | Test Loss: 0.0084 | Test Accuracy: 90.57
# Epoch 95 | Train Loss: 0.0006 | Train Accuracy: 98.59 | Test Loss: 0.0088 | Test Accuracy: 90.5
# Epoch 96 | Train Loss: 0.0006 | Train Accuracy: 98.6 | Test Loss: 0.0087 | Test Accuracy: 90.7
# Epoch 97 | Train Loss: 0.0006 | Train Accuracy: 98.56 | Test Loss: 0.0084 | Test Accuracy: 90.54
# Epoch 98 | Train Loss: 0.0006 | Train Accuracy: 98.55 | Test Loss: 0.0091 | Test Accuracy: 90.62
# Epoch 99 | Train Loss: 0.0005 | Train Accuracy: 98.73 | Test Loss: 0.0106 | Test Accuracy: 89.94
# Epoch 100 | Train Loss: 0.0006 | Train Accuracy: 98.63 | Test Loss: 0.0090 | Test Accuracy: 90.69

# %%
method = 'Shape-Memory Dropout (Only training)'
dataset = 'FMNIST'
exp_num = '0'
save = False
plot(method, dataset, exp_num, train_loss_list, train_acc_list, test_loss_list, test_acc_list, save)
